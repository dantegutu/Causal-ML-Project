# %%
import numpy as np
import pandas as pd
import datetime as dt

# Importing fundamental data from CSV file
df = pd.read_csv("MSCI Q New.csv")
df = df.drop(["fqtr", "fyearq"], axis = 1)
# Out:
#         gvkey  datadate        atq        ltq      piq    saleq  txtq  \
# 0        8544  20000630  301477.00        NaN      NaN      NaN   NaN
# 1        8544  20001231  328496.00  241259.00      NaN      NaN   NaN
# 2        8544  20010630        NaN        NaN      NaN      NaN   NaN
# 3        8544  20011231  307622.00  218041.00      NaN      NaN   NaN
# 4        8544  20020630  304901.80  213157.70      NaN      NaN   NaN
# ...       ...       ...        ...        ...      ...      ...   ...
# 56776  349758  20201231   69883.21    6621.00 -3513.00   6094.0  13.0
# 56777  349758  20210331   87035.43    6105.35 -1342.29   6924.4   0.0
# 56778  349758  20210630        NaN        NaN -3590.00   8444.0  17.0
# 56779  349758  20210930  173147.00    8358.00 -4349.00  10242.0   NaN
# 56780  349758  20211231        NaN        NaN  -672.00  11120.0   NaN
#
#              conm
# 0        PLDT INC
# 1        PLDT INC
# 2        PLDT INC
# 3        PLDT INC
# 4        PLDT INC
# ...           ...
# 56776  ZOMATO LTD
# 56777  ZOMATO LTD
# 56778  ZOMATO LTD
# 56779  ZOMATO LTD
# 56780  ZOMATO LTD
#
# [56781 rows x 8 columns]

# %%
# Keeping only fundamental data from 2005 onwards
df = df[df.datadate >= 20050101]
# Out:
#         gvkey  datadate        atq        ltq       piq    saleq    txtq  \
# 12       8544  20050331  261403.00  207020.00  12714.00  30144.0  3475.0
# 13       8544  20050630  263189.00  203885.00   9585.00  30887.0  2151.0
# 14       8544  20050930  257074.00  188768.00  10625.00  31424.0  2417.0
# 15       8544  20051231  251984.00  177615.00   5691.00  33268.0 -3907.0
# 16       8544  20060331  251110.00  174358.00  11277.00  30879.0  2512.0
# ...       ...       ...        ...        ...       ...      ...     ...
# 56776  349758  20201231   69883.21    6621.00  -3513.00   6094.0    13.0
# 56777  349758  20210331   87035.43    6105.35  -1342.29   6924.4     0.0
# 56778  349758  20210630        NaN        NaN  -3590.00   8444.0    17.0
# 56779  349758  20210930  173147.00    8358.00  -4349.00  10242.0     NaN
# 56780  349758  20211231        NaN        NaN   -672.00  11120.0     NaN
#
#              conm
# 12       PLDT INC
# 13       PLDT INC
# 14       PLDT INC
# 15       PLDT INC
# 16       PLDT INC
# ...           ...
# 56776  ZOMATO LTD
# 56777  ZOMATO LTD
# 56778  ZOMATO LTD
# 56779  ZOMATO LTD
# 56780  ZOMATO LTD
#
# [52016 rows x 8 columns]

# %%
# Importing forex data and setting index to dates
fx = pd.read_csv("exchange_rates.csv")
fx= fx.set_index("ANNDATS")

cur_codes = fx.CURR.unique()

# Generating currency dictionary with the different currencies being the dictionaries keys
curr_dict = {}
for cur in cur_codes:
    info = fx[fx["CURR"] == cur]
    info = info.drop(["CURR"], axis=1)
    curr_dict[cur] = info

curr_dict
# Out:
# {'AED':            EXRAT               CURNAM
#  ANNDATS
#  20000103  3.6729  United Arab Dirhams
#  20000104  3.6731  United Arab Dirhams
#  20000105  3.6730  United Arab Dirhams
#  20000106  3.6729  United Arab Dirhams
#  20000107  3.6732  United Arab Dirhams
#  ...          ...                  ...
#  20211227  3.6726  United Arab Dirhams
#  20211228  3.6726  United Arab Dirhams
#  20211229  3.6726  United Arab Dirhams
#  20211230  3.6726  United Arab Dirhams
#  20211231  3.6726  United Arab Dirhams
#
#  [5717 rows x 2 columns],
#  'ARS':                EXRAT          CURNAM
#  ANNDATS
#  20000103    0.999800  Argentine Peso
#  20000104    0.999900  Argentine Peso
#  20000105    0.999900  Argentine Peso
#  20000106    0.999900  Argentine Peso
#  20000107    0.999500  Argentine Peso
#  ...              ...             ...
#  20211227  102.540001  Argentine Peso
#  20211228  102.599998  Argentine Peso
#  20211229  102.629997  Argentine Peso
#  20211230  102.680000  Argentine Peso
#  20211231  102.680000  Argentine Peso
#
#  [5717 rows x 2 columns],
#  'AUD':             EXRAT             CURNAM
#  ANNDATS
#  20000103  1.51520  Australian Dollar
#  20000104  1.52090  Australian Dollar
#  20000105  1.52150  Australian Dollar
#  20000106  1.52640  Australian Dollar
#  20000107  1.52560  Australian Dollar
#  ...           ...                ...
#  20211227  1.38236  Australian Dollar
#  20211228  1.38351  Australian Dollar
#  20211229  1.37969  Australian Dollar
#  20211230  1.37950  Australian Dollar
#  20211231  1.37741  Australian Dollar
#
#  [5717 rows x 2 columns],
#  'BEF':               EXRAT         CURNAM
#  ANNDATS
#  20000103  39.382896  Belgian Franc
#  20000104  39.180168  Belgian Franc
#  20000105  39.085262  Belgian Franc
#  20000106  39.058773  Belgian Franc
#  20000107  39.183971  Belgian Franc
#  ...             ...            ...
#  20211227  29.528162  Belgian Franc
#  20211228  29.528162  Belgian Franc
#  20211229  29.528162  Belgian Franc
#  20211230  29.528162  Belgian Franc
#  20211231  29.528162  Belgian Franc
#
#  [5697 rows x 2 columns],
#  'BRL':            EXRAT                        CURNAM
#  ANNDATS
#  20000103  1.7975  Brazilian Real (1000 shares)
#  20000104  1.8355  Brazilian Real (1000 shares)
#  20000105  1.8585  Brazilian Real (1000 shares)
#  20000106  1.8395  Brazilian Real (1000 shares)
#  20000107  1.8305  Brazilian Real (1000 shares)
#  ...          ...                           ...
#  20211227  5.6249  Brazilian Real (1000 shares)
#  20211228  5.6283  Brazilian Real (1000 shares)
#  20211229  5.7032  Brazilian Real (1000 shares)
#  20211230  5.5710  Brazilian Real (1000 shares)
#  20211231  5.5703  Brazilian Real (1000 shares)
#
#  [5717 rows x 2 columns],
#  'CHF':            EXRAT       CURNAM
#  ANNDATS
#  20000103  1.5818  Swiss Franc
#  20000104  1.5570  Swiss Franc
#  20000105  1.5521  Swiss Franc
#  20000106  1.5514  Swiss Franc
#  20000107  1.5623  Swiss Franc
#  ...          ...          ...
#  20211227  0.9172  Swiss Franc
#  20211228  0.9174  Swiss Franc
#  20211229  0.9146  Swiss Franc
#  20211230  0.9134  Swiss Franc
#  20211231  0.9122  Swiss Franc
#
#  [5717 rows x 2 columns],
#  'CLP':                EXRAT        CURNAM
#  ANNDATS
#  20000103  527.849976  Chilean Peso
#  20000104  529.049988  Chilean Peso
#  20000105  529.349976  Chilean Peso
#  20000106  526.450012  Chilean Peso
#  20000107  522.299988  Chilean Peso
#  ...              ...           ...
#  20211227  856.049988  Chilean Peso
#  20211228  853.869995  Chilean Peso
#  20211229  848.250000  Chilean Peso
#  20211230  851.099976  Chilean Peso
#  20211231  851.099976  Chilean Peso
#
#  [5716 rows x 2 columns],
#  'CNY':            EXRAT            CURNAM
#  ANNDATS
#  20000103  8.2798  Chinese Renminbi
#  20000104  8.2799  Chinese Renminbi
#  20000105  8.2798  Chinese Renminbi
#  20000106  8.2797  Chinese Renminbi
#  20000107  8.2794  Chinese Renminbi
#  ...          ...               ...
#  20211227  6.3705  Chinese Renminbi
#  20211228  6.3684  Chinese Renminbi
#  20211229  6.3680  Chinese Renminbi
#  20211230  6.3691  Chinese Renminbi
#  20211231  6.3521  Chinese Renminbi
#
#  [5717 rows x 2 columns],
#  'COP':                 EXRAT          CURNAM
#  ANNDATS
#  20000103  1877.500000  Colombian Peso
#  20000104  1902.500000  Colombian Peso
#  20000105  1919.250000  Colombian Peso
#  20000106  1911.000000  Colombian Peso
#  20000107  1905.250000  Colombian Peso
#  ...               ...             ...
#  20211227  3996.600098  Colombian Peso
#  20211228  4005.600098  Colombian Peso
#  20211229  4034.459961  Colombian Peso
#  20211230  4065.409912  Colombian Peso
#  20211231  4065.409912  Colombian Peso
#
#  [5716 rows x 2 columns],
#  'CZK':               EXRAT        CURNAM
#  ANNDATS
#  20000103  35.560001  Czech Koruna
#  20000104  35.263500  Czech Koruna
#  20000105  35.085999  Czech Koruna
#  20000106  35.008999  Czech Koruna
#  20000107  35.017502  Czech Koruna
#  ...             ...           ...
#  20211227  22.117001  Czech Koruna
#  20211228  22.024000  Czech Koruna
#  20211229  21.974001  Czech Koruna
#  20211230  21.934999  Czech Koruna
#  20211231  21.849001  Czech Koruna
#
#  [5717 rows x 2 columns],
#  'DEM':              EXRAT              CURNAM
#  ANNDATS
#  20000103  1.909431  German Deutschmark
#  20000104  1.899602  German Deutschmark
#  20000105  1.895000  German Deutschmark
#  20000106  1.893716  German Deutschmark
#  20000107  1.899786  German Deutschmark
#  ...            ...                 ...
#  20211227  1.431636  German Deutschmark
#  20211228  1.431636  German Deutschmark
#  20211229  1.431636  German Deutschmark
#  20211230  1.431636  German Deutschmark
#  20211231  1.431636  German Deutschmark
#
#  [5697 rows x 2 columns],
#  'DKK':            EXRAT        CURNAM
#  ANNDATS
#  20000103  7.3300  Danish Krone
#  20000104  7.2247  Danish Krone
#  20000105  7.2021  Danish Krone
#  20000106  7.1869  Danish Krone
#  20000107  7.2309  Danish Krone
#  ...          ...           ...
#  20211227  6.5642  Danish Krone
#  20211228  6.5742  Danish Krone
#  20211229  6.5522  Danish Krone
#  20211230  6.5664  Danish Krone
#  20211231  6.5405  Danish Krone
#
#  [5717 rows x 2 columns],
#  'EGP':             EXRAT          CURNAM
#  ANNDATS
#  20000103   3.4248  Egyptian Pound
#  20000104   3.4270  Egyptian Pound
#  20000105   3.4248  Egyptian Pound
#  20000106   3.4270  Egyptian Pound
#  20000107   3.4270  Egyptian Pound
#  ...           ...             ...
#  20211227  15.6800  Egyptian Pound
#  20211228  15.7000  Egyptian Pound
#  20211229  15.6600  Egyptian Pound
#  20211230  15.6600  Egyptian Pound
#  20211231  15.6600  Egyptian Pound
#
#  [5717 rows x 2 columns],
#  'ESP':                EXRAT          CURNAM
#  ANNDATS
#  20000103  162.438736  Spanish Paseta
#  20000104  161.602570  Spanish Paseta
#  20000105  161.211121  Spanish Paseta
#  20000106  161.101852  Spanish Paseta
#  20000107  161.618256  Spanish Paseta
#  ...              ...             ...
#  20211227  121.791893  Spanish Paseta
#  20211228  121.791893  Spanish Paseta
#  20211229  121.791893  Spanish Paseta
#  20211230  121.791893  Spanish Paseta
#  20211231  121.791893  Spanish Paseta
#
#  [5697 rows x 2 columns],
#  'EUR':              EXRAT CURNAM
#  ANNDATS
#  20000103  0.976276   Euro
#  20000104  0.971251   Euro
#  20000105  0.968898   Euro
#  20000106  0.968242   Euro
#  20000107  0.971345   Euro
#  ...            ...    ...
#  20211227  0.883000   Euro
#  20211228  0.884250   Euro
#  20211229  0.881210   Euro
#  20211230  0.883160   Euro
#  20211231  0.879660   Euro
#
#  [5729 rows x 2 columns],
#  'FRF':              EXRAT        CURNAM
#  ANNDATS
#  20000103  6.403954  French Franc
#  20000104  6.370989  French Franc
#  20000105  6.355556  French Franc
#  20000106  6.351249  French Franc
#  20000107  6.371608  French Franc
#  ...            ...           ...
#  20211227  4.801500  French Franc
#  20211228  4.801500  French Franc
#  20211229  4.801500  French Franc
#  20211230  4.801500  French Franc
#  20211231  4.801500  French Franc
#
#  [5696 rows x 2 columns],
#  'GBP':             EXRAT                   CURNAM
#  ANNDATS
#  20000103  0.61590  British Pounds Sterling
#  20000104  0.61140  British Pounds Sterling
#  20000105  0.61010  British Pounds Sterling
#  20000106  0.60690  British Pounds Sterling
#  20000107  0.61050  British Pounds Sterling
#  ...           ...                      ...
#  20211227  0.74421  British Pounds Sterling
#  20211228  0.74438  British Pounds Sterling
#  20211229  0.74151  British Pounds Sterling
#  20211230  0.74107  British Pounds Sterling
#  20211231  0.73915  British Pounds Sterling
#
#  [5709 rows x 2 columns],
#  'GRD':                EXRAT         CURNAM
#  ANNDATS
#  20000103  321.920013  Greek Drachma
#  20000104  320.820007  Greek Drachma
#  20000105  320.029999  Greek Drachma
#  20000106  319.609985  Greek Drachma
#  20000107  321.209991  Greek Drachma
#  ...              ...            ...
#  20211227  249.423553  Greek Drachma
#  20211228  249.423553  Greek Drachma
#  20211229  249.423553  Greek Drachma
#  20211230  249.423553  Greek Drachma
#  20211231  249.423553  Greek Drachma
#
#  [5685 rows x 2 columns],
#  'HKD':            EXRAT            CURNAM
#  ANNDATS
#  20000103  7.7763  Hong Kong Dollar
#  20000104  7.7774  Hong Kong Dollar
#  20000105  7.7778  Hong Kong Dollar
#  20000106  7.7779  Hong Kong Dollar
#  20000107  7.7777  Hong Kong Dollar
#  ...          ...               ...
#  'QAR':            EXRAT       CURNAM
#  ANNDATS
#  20021118  3.6414  Qatari Rial
#  20021119  3.6414  Qatari Rial
#  20021120  3.6409  Qatari Rial
#  20021121  3.6407  Qatari Rial
#  20021122  3.6411  Qatari Rial
#  ...          ...          ...
#  20211227  3.6415  Qatari Rial
#  20211228  3.6400  Qatari Rial
#  20211229  3.6400  Qatari Rial
#  20211230  3.6415  Qatari Rial
#  20211231  3.6415  Qatari Rial
#
#  [4981 rows x 2 columns],
#  'RUB':               EXRAT         CURNAM
#  ANNDATS
#  20030804  30.320000  Russian Ruble
#  20030805  30.305599  Russian Ruble
#  20030806  30.297199  Russian Ruble
#  20030807  30.344999  Russian Ruble
#  20030808  30.413200  Russian Ruble
#  ...             ...            ...
#  20211227  73.149498  Russian Ruble
#  20211228  73.552803  Russian Ruble
#  20211229  73.641899  Russian Ruble
#  20211230  74.481697  Russian Ruble
#  20211231  74.560699  Russian Ruble
#
#  [4792 rows x 2 columns],
#  'SAR':            EXRAT       CURNAM
#  ANNDATS
#  20000103  3.7503  Saudi Riyal
#  20000104  3.7505  Saudi Riyal
#  20000105  3.7504  Saudi Riyal
#  20000106  3.7504  Saudi Riyal
#  20000107  3.7505  Saudi Riyal
#  ...          ...          ...
#  20211227  3.7550  Saudi Riyal
#  20211228  3.7556  Saudi Riyal
#  20211229  3.7530  Saudi Riyal
#  20211230  3.7538  Saudi Riyal
#  20211231  3.7538  Saudi Riyal
#
#  [5714 rows x 2 columns],
#  'SEK':            EXRAT         CURNAM
#  ANNDATS
#  20000103  8.4400  Swedish Krona
#  20000104  8.3630  Swedish Krona
#  20000105  8.3520  Swedish Krona
#  20000106  8.3510  Swedish Krona
#  20000107  8.4240  Swedish Krona
#  ...          ...            ...
#  20211227  9.0925  Swedish Krona
#  20211228  9.0464  Swedish Krona
#  20211229  9.0274  Swedish Krona
#  20211230  9.0179  Swedish Krona
#  20211231  9.0392  Swedish Krona
#
#  [5717 rows x 2 columns],
#  'SGD':            EXRAT            CURNAM
#  ANNDATS
#  20000103  1.6558  Singapore Dollar
#  20000104  1.6530  Singapore Dollar
#  20000105  1.6567  Singapore Dollar
#  20000106  1.6653  Singapore Dollar
#  20000107  1.6615  Singapore Dollar
#  ...          ...               ...
#  20211227  1.3568  Singapore Dollar
#  20211228  1.3534  Singapore Dollar
#  20211229  1.3521  Singapore Dollar
#  20211230  1.3520  Singapore Dollar
#  20211231  1.3490  Singapore Dollar
#
#  [5717 rows x 2 columns],
#  'THB':               EXRAT         CURNAM
#  ANNDATS
#  20000103  36.970001  Thailand Baht
#  20000104  37.150002  Thailand Baht
#  20000105  37.185001  Thailand Baht
#  20000106  37.605000  Thailand Baht
#  20000107  37.345001  Thailand Baht
#  ...             ...            ...
#  20211227  33.520000  Thailand Baht
#  20211228  33.529999  Thailand Baht
#  20211229  33.500000  Thailand Baht
#  20211230  33.340000  Thailand Baht
#  20211231  33.230000  Thailand Baht
#
#  [5717 rows x 2 columns],
#  'TRL':               EXRAT        CURNAM
#  ANNDATS
#  20000103   539745.0  Turkish Lira
#  20000104   536490.0  Turkish Lira
#  20000105   536705.0  Turkish Lira
#  20000106   536485.0  Turkish Lira
#  20000107   539205.0  Turkish Lira
#  ...             ...           ...
#  20211227  1348500.0  Turkish Lira
#  20211228  1348500.0  Turkish Lira
#  20211229  1348500.0  Turkish Lira
#  20211230  1348500.0  Turkish Lira
#  20211231  1348500.0  Turkish Lira
#
#  [5683 rows x 2 columns],
#  'TRY':               EXRAT            CURNAM
#  ANNDATS
#  20000103   0.539745  New Turkish Lira
#  20000104   0.536490  New Turkish Lira
#  20000105   0.536705  New Turkish Lira
#  20000106   0.536485  New Turkish Lira
#  20000107   0.539205  New Turkish Lira
#  ...             ...               ...
#  20211227  11.680100  New Turkish Lira
#  20211228  11.797800  New Turkish Lira
#  20211229  12.635900  New Turkish Lira
#  20211230  12.948100  New Turkish Lira
#  20211231  13.316100  New Turkish Lira
#
#  [5717 rows x 2 columns],
#  'TWD':               EXRAT         CURNAM
#  ANNDATS
#  20000103  31.388000  Taiwan Dollar
#  20000104  30.576000  Taiwan Dollar
#  20000105  30.764999  Taiwan Dollar
#  20000106  30.850000  Taiwan Dollar
#  20000107  30.848000  Taiwan Dollar
#  ...             ...            ...
#  20211227  27.687000  Taiwan Dollar
#  20211228  27.629999  Taiwan Dollar
#  20211229  27.636000  Taiwan Dollar
#  20211230  27.722000  Taiwan Dollar
#  20211231  27.712000  Taiwan Dollar
#
#  [5717 rows x 2 columns],
#  'USD':           EXRAT       CURNAM
#  ANNDATS
#  20000103    1.0  U.S. Dollar
#  20000104    1.0  U.S. Dollar
#  20000105    1.0  U.S. Dollar
#  20000106    1.0  U.S. Dollar
#  20000107    1.0  U.S. Dollar
#  ...         ...          ...
#  20211227    1.0  U.S. Dollar
#  20211228    1.0  U.S. Dollar
#  20211229    1.0  U.S. Dollar
#  20211230    1.0  U.S. Dollar
#  20211231    1.0  U.S. Dollar
#
#  [5700 rows x 2 columns],
#  'VND':                  EXRAT           CURNAM
#  ANNDATS
#  20021118  15377.000000  Vietnamese Dong
#  20021119  15377.000000  Vietnamese Dong
#  20021120  15376.000000  Vietnamese Dong
#  20021121  24279.599609  Vietnamese Dong
#  20021122  15380.000000  Vietnamese Dong
#  ...                ...              ...
#  20211227  22810.000000  Vietnamese Dong
#  20211228  22835.000000  Vietnamese Dong
#  20211229  22820.000000  Vietnamese Dong
#  20211230  22765.000000  Vietnamese Dong
#  20211231  22825.000000  Vietnamese Dong
#
#  [4979 rows x 2 columns],
#  'ZAR':             EXRAT              CURNAM
#  ANNDATS
#  20000103   6.1200  South African Rand
#  20000104   6.1150  South African Rand
#  20000105   6.0745  South African Rand
#  20000106   6.0750  South African Rand
#  20000107   6.0522  South African Rand
#  ...           ...                 ...
#  20211227  15.5338  South African Rand
#  20211228  15.7554  South African Rand
#  20211229  15.9299  South African Rand
#  20211230  15.9220  South African Rand
#  20211231  15.9921  South African Rand
#
#  [5717 rows x 2 columns]}

# %%
# Setting index of fundamental dataframe to the date 
df = df.set_index("datadate")

# %%
# Generating the D/E, ROA, and ROE ratios for each quarter
df["D/E"] = df["ltq"]/(df["atq"] - df["ltq"])
df["ROA"] = (df["piq"] - df["txtq"])/df["atq"]
df["ROE"] = (df["piq"] - df["txtq"])/(df["atq"] - df["ltq"])

# %%
# Retrieving the unique company names
stock_names = df.conm.unique()

# Dictionary for the fundamental data with company names being the dictionary's keys
test_dict = {}
dup = []
for name in stock_names:
    # Getting company subset information from original df
    info = df[df["conm"] == name]
    info = info.drop(["conm"], axis=1)
    # For each company, create an empty column to calculate the SGI
    info["SGI"] = None
    test_dict[name] = info

# %%
# For each company, drop duplicates from fundamental data - keep the first entry for two cases (full data), 
# keep last for the other companies 
for name in stock_names:
    test_dict[name] = test_dict[name].reset_index()
    if name in ['BEIJING ENTERPRISES WATER GR','NATL INDUSTRIALIZATION CO']:
        test_dict[name] = test_dict[name].drop_duplicates(subset = ['datadate'], keep = "first")
    else:
        test_dict[name] = test_dict[name].drop_duplicates(subset = ['datadate'], keep = "last")
    # Reset index back to dates
    test_dict[name] = test_dict[name].set_index('datadate')


    info = test_dict[name]
    # Sort dates by date (from earliest to latest)
    dates = info.index.unique().sort_values(ascending = True)
    for j in range(len(dates)):
        # Check if it is the first date available, set growth index to 1, otherwise, perform SGI calculation
        if (j == 0):
            info.loc[dates[j], "SGI"] = 1
        else:
            info.loc[dates[j], "SGI"] = info.loc[dates[j],"saleq"]/info.loc[dates[j-1], "saleq"]
    test_dict[name] = info
# Out:
# /var/folders/l7/9x99jj25655fgy_97606f5740000gn/T/ipykernel_4574/1193468550.py:16: RuntimeWarning: invalid value encountered in double_scalars
#   info.loc[dates[j], "SGI"] = info.loc[dates[j],"saleq"]/info.loc[dates[j-1], "saleq"]
# /var/folders/l7/9x99jj25655fgy_97606f5740000gn/T/ipykernel_4574/1193468550.py:16: RuntimeWarning: divide by zero encountered in double_scalars
#   info.loc[dates[j], "SGI"] = info.loc[dates[j],"saleq"]/info.loc[dates[j-1], "saleq"]

# %%
# Import daily price data from CSV file - keep only the dates begining with New Year's Day 2005
daily = pd.read_csv("MSCI Cur Codes.csv")
daily = daily[daily.datadate >= 20050101]

# %%
# Set daily price dataframe index to dates
daily = daily.set_index("datadate")
daily = daily.drop("iid", axis=1)
# Out:
# 976

# %%
# Creating a dictionary for each asset's daily price history
prices_dict = {}
for name in stock_names:
    info = daily[daily["conm"] == name]
    #info = info.drop(["conm", "ajexdi", "trfd"], axis=1)
    
    #Drop company name from the subset 
    info = info.drop(["conm"], axis=1)
    # Drop any rows that have at least 4 columns that are NaN or None 
    info = info.dropna(thresh = 4)
    # Create empty column for the closing price expressed in USD
    info["PriceUSD"] = None
    prices_dict[name] = info

prices_dict
# Out:
# {'PLDT INC':           gvkey curcdd  ajexdi    prccd      trfd PriceUSD
#  datadate
#  20050103   8544    PHP     1.0  1390.00  1.078887     None
#  20050104   8544    PHP     1.0  1390.00  1.078887     None
#  20050105   8544    PHP     1.0  1390.00  1.078887     None
#  20050106   8544    PHP     1.0  1355.00  1.078887     None
#  20050107   8544    PHP     1.0  1345.00  1.078887     None
#  ...         ...    ...     ...      ...       ...      ...
#  20110915   8544    PHP     1.0    12.00  2.650862     None
#  20110920   8544    PHP     1.0    11.50  2.650862     None
            gvkey curcdd  ajexdi    prccd      trfd PriceUSD
#  datadate
#  20050103  104584    KRW  1.0708  27500.0  1.783151     None
#  20050104  104584    KRW  1.0708  27250.0  1.783151     None
#  20050105  104584    KRW  1.0708  27800.0  1.783151     None
#  20050106  104584    KRW  1.0708  27900.0  1.783151     None
#  20050107  104584    KRW  1.0708  27900.0  1.783151     None
#  ...          ...    ...     ...      ...       ...      ...
#  20211227  104584    KRW  1.0000  41250.0  2.165781     None
#  20211228  104584    KRW  1.0000  41350.0  2.165781     None
#  20211229  104584    KRW  1.0000  40500.0  2.235299     None
#  20211230  104584    KRW  1.0000  39600.0  2.235299     None
#  20211231  104584    KRW  1.0000  39600.0  2.235299     None
#
#  [4377 rows x 6 columns],
#  'HYUNDAI STEEL CO':            gvkey curcdd  ajexdi    prccd      trfd PriceUSD
#  datadate
#  20050103  104593    KRW     1.0  13050.0  1.591867     None
#  20050104  104593    KRW     1.0  13100.0  1.591867     None
#  20050105  104593    KRW     1.0  12850.0  1.591867     None
#  20050106  104593    KRW     1.0  12800.0  1.591867     None
#  20050107  104593    KRW     1.0  12950.0  1.591867     None
#  ...          ...    ...     ...      ...       ...      ...
#  20100304  104593    KRW     1.0  86200.0  1.125516     None
#  20100305  104593    KRW     1.0  87400.0  1.125516     None
#  20100308  104593    KRW     1.0  90700.0  1.125516     None
#  20100309  104593    KRW     1.0  90800.0  1.125516     None
#  20100310  104593    KRW     1.0  89800.0  1.125516     None
#
#  [5654 rows x 6 columns],
#  'POSCO HOLDINGS INC':            gvkey curcdd  ajexdi      prccd      trfd PriceUSD
#  datadate
#  20050103  104598    KRW     1.0  185000.00  1.354250     None
#  20050104  104598    KRW     1.0  182500.00  1.354250     None
#  20050105  104598    KRW     1.0  180000.00  1.354250     None
#  20050106  104598    KRW     1.0  178000.00  1.354250     None
#  20050107  104598    KRW     1.0  176500.00  1.354250     None
#  ...          ...    ...     ...        ...       ...      ...
#  20140221  104598    SGD     1.0     101.62  1.074965     None
#  20140224  104598    SGD     1.0     101.62  1.074965     None
#  20140225  104598    SGD     1.0     101.62  1.074965     None
#  20140226  104598    SGD     1.0     101.62  1.074965     None
#  20140227  104598    SGD     1.0     101.62  1.074965     None
#
#  [7697 rows x 6 columns],
#  'SAMSUNG ELECTRO-MECHANICS CO':            gvkey curcdd  ajexdi     prccd      trfd PriceUSD
#  datadate
#  20050103  104602    KRW     1.0   26150.0  1.228108     None
#  20050104  104602    KRW     1.0   26350.0  1.228108     None
#  20050105  104602    KRW     1.0   26500.0  1.228108     None
#  20050106  104602    KRW     1.0   26900.0  1.228108     None
#  20050107  104602    KRW     1.0   26600.0  1.228108     None
#  ...          ...    ...     ...       ...       ...      ...
#  20211227  104602    KRW     1.0  106500.0  2.140675     None
#  20211228  104602    KRW     1.0  105500.0  2.140675     None
#  20211229  104602    KRW     1.0  106000.0  2.184095     None
#  20211230  104602    KRW     1.0  105000.0  2.184095     None
#  20211231  104602    KRW     1.0  105000.0  2.184095     None
#
#  [8754 rows x 6 columns],
#  'SAMSUNG ELECTRONICS CO LTD':            gvkey curcdd  ajexdi     prccd      trfd PriceUSD
#  datadate
#  20050103  104604    KRW    50.0  299000.0  1.333610     None
#  20050104  104604    KRW    50.0  299500.0  1.333610     None
#  20050105  104604    KRW    50.0  292500.0  1.333610     None
#  20050106  104604    KRW    50.0  288000.0  1.333610     None
#  20050107  104604    KRW    50.0  290000.0  1.333610     None
#  ...          ...    ...     ...       ...       ...      ...
#  20211227  104604    EUR     1.0    1342.0  1.125896     None
#  20211228  104604    EUR     1.0    1342.0  1.125896     None
#  20211229  104604    EUR     1.0    1332.0  1.125896     None
#  20211230  104604    EUR     1.0    1324.0  1.131409     None
#  20211231  104604    EUR     1.0    1324.0  1.131409     None
#
#  [35596 rows x 6 columns],
#  'KIA CORPORATION':            gvkey curcdd  ajexdi    prccd      trfd PriceUSD
#  datadate
#  20050103  104606    KRW     1.0  10600.0  1.093729     None
#  20050104  104606    KRW     1.0  10600.0  1.093729     None
#  20050105  104606    KRW     1.0  10550.0  1.093729     None
#  20050106  104606    KRW     1.0  10500.0  1.093729     None
#  20050107  104606    KRW     1.0  10650.0  1.093729     None
#  ...          ...    ...     ...      ...       ...      ...
#  20211227  104606    KRW     1.0  84800.0  1.367811     None
#  20211228  104606    KRW     1.0  84500.0  1.367811     None
#  20211229  104606    KRW     1.0  83400.0  1.417012     None
#  20211230  104606    KRW     1.0  82200.0  1.417012     None
#  20211231  104606    KRW     1.0  82200.0  1.417012     None
#
#  [4377 rows x 6 columns],
#  'HYUNDAI MOTOR CO LTD':            gvkey curcdd  ajexdi    prccd      trfd PriceUSD
#  datadate
#  20050103  104607    KRW     1.0  55500.0  1.319576     None
#  20050104  104607    KRW     1.0  54800.0  1.319576     None
#  20050105  104607    KRW     1.0  54700.0  1.319576     None
#  20050106  104607    KRW     1.0  53600.0  1.319576     None
#  20050107  104607    KRW     1.0  54700.0  1.319576     None
#  ...          ...    ...     ...      ...       ...      ...
#  20211227  104607    USD     1.0     42.2  1.098463     None
#  20211228  104607    USD     1.0     42.2  1.098463     None
#  20211229  104607    USD     1.0     42.2  1.098463     None
#  20211230  104607    USD     1.0     40.1  1.098463     None
#  20211231  104607    USD     1.0     40.1  1.098463     None
#
#  [35953 rows x 6 columns],
#  'LG CORP':            gvkey curcdd  ajexdi    prccd       trfd PriceUSD
#  datadate
#  20050103  104608    KRW  0.9116  17650.0  10.628071     None
#  20050104  104608    KRW  0.9116  17950.0  10.628071     None
#  20050105  104608    KRW  0.9116  18500.0  10.628071     None
#  20050106  104608    KRW  0.9116  17750.0  10.628071     None
#  20050107  104608    KRW  0.9116  18000.0  10.628071     None
#  ...          ...    ...     ...      ...        ...      ...
#  20211227  104608    KRW  1.0000  65000.0  10.573306     None
#  20211228  104608    KRW  1.0000  65400.0  10.573306     None
#  20211229  104608    KRW  1.0000  64000.0  11.044148     None
#  20211230  104608    KRW  1.0000  63600.0  11.044148     None
#  20211231  104608    KRW  1.0000  63600.0  11.044148     None
#
#  [8754 rows x 6 columns],
#  'SAMSUNG C&T CORPORATION':            gvkey curcdd  ajexdi    prccd      trfd PriceUSD
#  datadate
#  20050103
            gvkey curcdd  ajexdi  prccd      trfd PriceUSD
#  datadate
#  20210205  346434    HKD     1.0  300.0  1.010732     None
#  20210208  346434    HKD     1.0  303.0  1.010732     None
#  20210209  346434    HKD     1.0  350.6  1.010732     None
#  20210210  346434    HKD     1.0  397.0  1.010732     None
#  20210211  346434    HKD     1.0  398.0  1.010732     None
#  ...          ...    ...     ...    ...       ...      ...
#  20211227  346434    HKD     1.0   75.5  1.010732     None
#  20211228  346434    HKD     1.0   72.9  1.010732     None
#  20211229  346434    HKD     1.0   72.9  1.010732     None
#  20211230  346434    HKD     1.0   68.2  1.010732     None
#  20211231  346434    HKD     1.0   71.7  1.010732     None
#
#  [701 rows x 6 columns],
#  'MONTAGE TECHNOLOGY CO LTD':            gvkey curcdd  ajexdi  prccd      trfd PriceUSD
#  datadate
#  20190722  346559    CNY     1.0  74.92  1.000000     None
#  20190723  346559    CNY     1.0  74.13  1.000000     None
#  20190724  346559    CNY     1.0  75.88  1.000000     None
#  20190725  346559    CNY     1.0  78.00  1.000000     None
#  20190726  346559    CNY     1.0  71.68  1.000000     None
#  ...          ...    ...     ...    ...       ...      ...
#  20211227  346559    CNY     1.0  82.02  1.007398     None
#  20211228  346559    CNY     1.0  79.85  1.007398     None
#  20211229  346559    CNY     1.0  78.60  1.007398     None
#  20211230  346559    CNY     1.0  84.14  1.007398     None
#  20211231  346559    CNY     1.0  83.87  1.007398     None
#
#  [1202 rows x 6 columns],
#  'CHINA THREE GORGES RENEWABLE':            gvkey curcdd  ajexdi  prccd      trfd PriceUSD
#  datadate
#  20210610  347683    CNY     1.0   3.82  1.000000     None
#  20210611  347683    CNY     1.0   4.20  1.000000     None
#  20210614  347683    CNY     1.0   4.20  1.000000     None
#  20210615  347683    CNY     1.0   4.62  1.000000     None
#  20210616  347683    CNY     1.0   4.95  1.000000     None
#  ...          ...    ...     ...    ...       ...      ...
#  20211227  347683    CNY     1.0   7.69  1.005477     None
#  20211228  347683    CNY     1.0   7.47  1.005477     None
#  20211229  347683    CNY     1.0   7.25  1.005477     None
#  20211230  347683    CNY     1.0   7.32  1.005477     None
#  20211231  347683    CNY     1.0   7.51  1.005477     None
#
#  [164 rows x 6 columns],
#  'ZOMATO LTD':            gvkey curcdd  ajexdi   prccd      trfd PriceUSD
#  datadate
#  20210723  349758    INR     1.0  126.00  1.031613     None
#  20210726  349758    INR     1.0  140.65  1.031613     None
#  20210727  349758    INR     1.0  132.90  1.031613     None
#  20210728  349758    INR     1.0  131.20  1.031613     None
#  20210729  349758    INR     1.0  141.55  1.031613     None
#  ...          ...    ...     ...     ...       ...      ...
#  20211227  349758    INR     1.0  132.75  1.031613     None
#  20211228  349758    INR     1.0  132.85  1.031613     None
#  20211229  349758    INR     1.0  137.10  1.031613     None
#  20211230  349758    INR     1.0  133.95  1.031613     None
#  20211231  349758    INR     1.0  137.40  1.031613     None
#
#  [116 rows x 6 columns]}

# %%
# In order to deal with stocks that are potentially dual listed, 
# this function creates new dictionary that keeps the stocks that have at most 1 currency change
def get_stable_stocks(prices_dict, stock_names):
    # Create empty dictionary
    stable_stocks_dict = {}
    for name in stock_names:
        # Counter for the number of times the currecncy is different between subsequent rows 
        counter = 0
        dates = prices_dict[name].index.unique().sort_values(ascending = True)
        for i in range(1, len(dates)):
            # Check whether the currency from the current day to the prior day's currency is different 
            if (prices_dict[name].loc[dates[i], "curcdd"] != prices_dict[name].loc[dates[i-1], "curcdd"]):
                counter += 1
        # If counter is greater than 1, then do not at it to the new dictionary, and continue the for-loop
        if counter > 1:
            continue
        # Otherwise, add existing price information to the new dictionary    
        stable_stocks_dict[name] = prices_dict[name]
    # Once loop has completed, return the stable_stock dictionary   
    return stable_stocks_dict

# %%
# Function that converts the daily asset prices into USD 
def price_to_usd(prices_dict, stock_names):
    # Create a new dictionary 
    prices_dict_usd = {}
    # Run for loop across the asset names
    for name in stock_names:
        # Get available dates for asset's history in chronological order
        dates = prices_dict[name].index.unique().sort_values(ascending = True)
        # Create an empty df with the index being the available dates and a single column
        df = pd.DataFrame(index = dates, columns = ["PriceUSD"])
        check = []

        for j in range(len(dates)):
        # For each date available, 
        # try to search the forex dictionary for the exchange rate between the currency at the time and USD            
            try: 
                # Searching the currency dictionary for the exchange rate
                rate = curr_dict[prices_dict[name].loc[dates[j], "curcdd"]].loc[dates[j]][0]
                # Calculate the stock price in USD 
                df.loc[dates[j], "PriceUSD"] = ((prices_dict[name].loc[dates[j],"prccd"]/rate))
                # If rate is available, update the check array with the latest exchange rate 
                check.append(rate)
            except:
                # If the search draws an exception, first check if it is the first date available 
                if (j == 0):
                    # If first available date, break the loop and provide an empty df under that asset name
                    break
                else:
            # If after the first date available, use the last known exchange rate (check array) to determine USD price
                    df.loc[dates[j], "PriceUSD"] = ((prices_dict[name].loc[dates[j],"prccd"]/check[-1]))
                    #continue
                    
        # Assign the dictionary key the update dataframe
        prices_dict_usd[name] = df
    
    # Once loop has completed, return the USD dictionary
    return prices_dict_usd

# %%
# Function to drop duplicates by date from dictionary
def drop_dups(prices_dict, stock_names):  
    for name in stock_names:
        prices_dict[name] = prices_dict[name].reset_index()
        prices_dict[name] = prices_dict[name].drop_duplicates(subset = ['datadate'], keep = "first")
        prices_dict[name] = prices_dict[name].set_index('datadate')
    return prices_dict

# Function that computes gross daily returns from given dictionary
def daily_returns(prices_dict, stock_names):   
    for name in stock_names:
        # For each key, add empty column for returns
        prices_dict[name]["Ret"] = None
        dates = prices_dict[name].index.unique().sort_values(ascending = True)
        for j in range(len(dates)):
            # If first available date, set return for that date to zero
            if (j == 0):
                prices_dict[name].loc[dates[j], "Ret"] = 0
            # Otherwise calculate daily returns 
            else:
                prices_dict[name].loc[dates[j], "Ret"] = ((prices_dict[name].loc[dates[j],"price/adj*trfd"]/prices_dict[name].loc[dates[j-1], "price/adj*trfd"])-1)
    # Return update dictionary            
    return prices_dict

# %%
def monthly_returns(df, stock_names):
    # Getting a list of the months from Jan 05 to Dec 21 in the form YYYYMM
    months = pd.date_range('2005-01-01','2021-12-31', freq='MS').strftime("%Y%m").tolist()
    # Creating returns dictionary
    returns = {}
    for name in stock_names:
        # Creating empty dataframe 
        bb = pd.DataFrame()
        for month in months: 
            # Retrieve the dates for that dictionary key and convert to a list 
            dates = df[name].index.tolist()
            # Converting available dates to string
            str_dates = [str(k) for k in dates]
            # Boolean array to check for the rows that are in that month 
            bbc = [str(month) in k for k in str_dates]
            # Try searching for all the days that are within that month 
            try:
                monthly = df[name][bbc]
                # Create array with intial value being the month in question
                check = [month]
                # Append the check array with the return for that month. 
                # This is achieved using cumulative products and taking the past element of the cumprod method less one
                check.append((monthly["Ret"].add(1).cumprod(axis=0).iloc[-1])-1)
                # Create pandas time series for this data 
                add = pd.Series(check)
                # Add this monthly information to bb
                bb = bb.append(add, ignore_index = True)
            except:
                # If you cannot find the month, continue the for loop
                continue
        # Monthly returns for the given asset is then bb       
        returns[name] = bb
        # Columns names for the monthly return data are set
        returns[name].columns = ["Month", "MonthlyReturn"]
    # Once looping is complete, return the returns dictionary 
    return returns


# Function that converts monthly data to quarterly data 
def quarterly_returns(returns, stock_names):
    # Create quarterly returns dictionary
    q_returns = {}
    # Create an array for the years 2005-2021
    years = [year for year in range(2005,2022)]
    
    for name in stock_names:
        # Create empy dataframe 
        b = pd.DataFrame()
        # For each year, create months that fall into Q1, Q2, Q3, and Q4
        for year in years:
            q1 = [str(year) + "01", str(year) + "02", str(year) + "03"]
            q2 = [str(year) + "04", str(year) + "05", str(year) + "06"]
            q3 = [str(year) + "07", str(year) + "08", str(year) + "09"]
            q4 = [str(year) + "10", str(year) + "11", str(year) + "12"]
            # Array of each quarter for a given year 
            qs = [q1,q2,q3,q4]

            for q in qs:
                # For each quarter, initialise array with last month of each quarter 
                check = [q[-1]]
                try:
                    # Try to search for all the monthly returns that fall into that quarter 
                    # If found, take cumulative products of this subset, taking the last entry minus one 
                    # as the quarterly return for that asset
                    q_ret = (returns[name][[returns[name].loc[i, "Month"] in q for 
                                                i in range(len(returns[name]))]].MonthlyReturn.add(1).cumprod(axis=0).iloc[-1])-1

                    # Update check array with the quarterly return. Convert check to pandas series
                    check.append(q_ret)
                    check = pd.Series(check)
                except (IndexError):
                    # If no stocks are found for that quarter, continue for-loop to next quarter 
                    continue
                # Add row of information to dataframe b
                b = b.append(check, ignore_index = True)    
        # Once returns calculated for all available quarters, assign q_returns dictionary that information under the asset name key
        q_returns[name] = b
        q_returns[name].columns = ["Date", "QuarterReturn"]
    # Return q_returns once run across all available assets 
    return q_returns

# %%
prices_dict = drop_dups(prices_dict, prices_dict.keys())

# %%
stable_stock_dict = get_stable_stocks(prices_dict, prices_dict.keys())

# %%
prices_dict_usd = price_to_usd(stable_stock_dict, stable_stock_dict.keys())

# %%
# Calculate the gross USD price of each stock in prices_dict 
for stock in prices_dict_usd.keys():
    prices_dict_usd[stock]["price/adj*trfd"] = (prices_dict_usd[stock]["PriceUSD"]/
                                                prices_dict[stock]["ajexdi"])*prices_dict[stock]["trfd"]
    
prices_dict_usd
# Out:
# {'PLDT INC':            PriceUSD price/adj*trfd
#  datadate
#  20050103  24.744104      26.696098
#  20050104   24.75953      26.712742
#  20050105  24.730895      26.681847
#  20050106  24.088889      25.989195
#  20050107  23.943036      25.831836
#  ...             ...            ...
#  20211227  37.022292     115.506178
#  20211228   36.38878      113.52968
#  20211229  36.645111     114.329411
#  20211230  36.666667     114.396661
#  20211231  35.536378     110.870264
#
#  [4368 rows x 2 columns],
#  'PTT OIL AND RETAIL BUSINESS':           PriceUSD price/adj*trfd
#  datadate
#  20210211  0.979571       0.979571
#  20210212  0.979243       0.979243
#  20210215  1.137885       1.137885
#  20210216  1.093854       1.093854
#  20210217  0.983333       0.983333
#  ...            ...            ...
#  20211227  0.805489       0.815657
#  20211228  0.812705       0.822964
#  20211229  0.813433       0.823701
#  20211230  0.809838       0.820061
#  20211231  0.812519       0.822775
#
#  [232 rows x 2 columns],
#  'KUAISHOU TECHNOLOGY':            PriceUSD price/adj*trfd
#  datadate
#  20210205  38.696196      39.111473
#  20210208  39.085679      39.505135
#  20210209  45.229372      45.714761
#  20210210  51.211269      51.760854
#  20210211  51.336954      51.887887
#  ...             ...            ...
#  20211227   9.687264       9.791224
#  20211228   9.296898        9.39667
#  20211229   8.785881       8.880169
#  20211230   8.731553       8.825257
#  20211231   9.242156        9.34134
#
#  [236 rows x 2 columns],
#  'MONTAGE TECHNOLOGY CO LTD':            PriceUSD price/adj*trfd
#  datadate
#  20190722   10.88906       10.88906
#  20190723  10.776746      10.776746
#  20190724  11.042231      11.042231
#  20190725  11.351399      11.351399
#  20190726  10.420877      10.420877
#  ...             ...            ...
#  20211227  12.874971      12.970216
#  20211228  12.538471      12.631228
#  20211229  12.342965      12.434275
#  20211230  13.210658      13.308387
#  20211231  13.203508      13.301184
#
#  [640 rows x 2 columns],
#  'CHINA THREE GORGES RENEWABLE':           PriceUSD price/adj*trfd
#  datadate
#  20210610  0.597538       0.597538
#  20210611  0.656589       0.656589
#  20210614  0.656589       0.656589
#  20210615  0.721289       0.721289
#  20210616  0.773812       0.773812
#  ...            ...            ...
#  20211227  1.207127       1.213738
#  20211228  1.172979       1.179403
#  20211229  1.138505        1.14474
#  20211230  1.149299       1.155594
#  20211231  1.182286       1.188761
#
#  [147 rows x 2 columns],
#  'ZOMATO LTD':           PriceUSD price/adj*trfd
#  datadate
#  20210723  1.692979       1.746499
#  20210726  1.892237       1.952056
#  20210727   1.78394       1.840336
#  20210728   1.76131        1.81699
#  20210729  1.906526       1.966796
#  ...            ...            ...
#  20211227  1.770945       1.826929
#  20211228  1.778447       1.834669
#  20211229  1.838788       1.896917
#  20211230  1.800403       1.857319
#  20211231  1.845113       1.903442
#
#  [116 rows x 2 columns]}

# %%
daily_rets = daily_returns(prices_dict_usd, prices_dict_usd.keys())

# %%
monthly_rets = monthly_returns(daily_rets, daily_rets.keys())

# %%
quarterly_rets = quarterly_returns(monthly_rets, monthly_rets.keys())

# %%
# Function that retrieves fundamentals and the next six-month returns for a given time period
def get_date_info(df, date, date1, date2):
    # Create empty dataframe for row of information
    info = pd.DataFrame()
    for name in quarterly_rets.keys():
        # Retrieve fundamental date for that asset
        entry = df[name]
        try:   
            # Try searching for row of D/E, ROA, ROE, and SGI for that given date and convert to a list
            date_info = entry[entry.index == date].loc[:, ["D/E", "ROA", "ROE", "SGI"]].values.tolist()[0]
            # Create an array of the two next quarter returns of that asset
            array = [quarterly_rets[name][quarterly_rets[name].Date == date1].values.tolist()[0][-1],
                quarterly_rets[name][quarterly_rets[name].Date == date2].values.tolist()[0][-1]]
            # Increment array  by one 
            array = [x+1 for x in array]
            # Calculate 6-month return for that asset 
            ret = (np.cumprod(array)[-1]-1)
        except (RuntimeError, TypeError, NameError, IndexError):
            # If there are any exceptions, continue onto the next available asset
            continue
        
        # Add asset name and forward 6-month return to the fundamental list 
        date_info.append(name)
        date_info.append(ret)
        new_row = pd.Series(date_info)
        # If there are any pieces of missing data from the row, do not include that asset and continue onto next one
        if (new_row.isna().any().any() == True):
            continue
        else:
            # Otherwise, append info with this asset's information
            info = info.append(new_row, ignore_index = True)  
    # Set column names to relevant names and set the index to the asset names available 
    info.columns = ["D/E", "ROA", "ROE", "SGI", "Name", "Ret"]
    info = info.set_index("Name")
    # Return the full information for that given time period 
    return info

# %%
bbc = get_date_info(test_dict, 20070331, "200706", "200709")

# Function that ranks returns into quintiles and the other factors into terciles
def rank_factors(info):
    for item in info.columns.tolist():
        string = item + " Rank"
        if (item == "Ret"):
            info[string] = pd.qcut(info[item], 5, labels = [item + "1", item + "2", item + "3",
                                                         item + "4", item + "5"])
        else:
             info[string] = pd.qcut(info[item], 3, labels = [item + "1", item + "2", item + "3"])
    return info
sup = rank_factors(bbc)

# %%
# Functions that creates an array of lists of factors for each available asset
def fpg_prep(info):  
    # Drop the columns that do not contain the rankings 
    state = info.drop(["D/E", "ROA", "ROE", "SGI", "Ret"], axis=1)
    # Drop the returns ranked column and assign remaining info to new
    new = state.drop("Ret Rank", axis = 1)
    # Reset the index of state and drop the names column 
    state = state.reset_index().drop("Name", axis=1)

    final = []
    # For each row, append final with each row as an array of its own
    for i in range(len(state)):
        final.append(state.loc[i, state.columns].tolist())
    # Return both final and new 
    return final, new

groups, ranks = fpg_prep(sup)
# Out:
#                              D/E Rank ROA Rank ROE Rank SGI Rank
# Name
# PLDT INC                         D/E3     ROA2     ROE3     SGI2
# ANGLO AMERICAN PLATINUM LTD      D/E2     ROA3     ROE3     SGI3
# SIBANYE-STILLWATER LIMITED       D/E2     ROA3     ROE3     SGI3
# AFRICAN RAINBOW MINERALS LTD     D/E1     ROA3     ROE3     SGI3
# KUALA LUMPUR KEPONG BHD          D/E2     ROA2     ROE1     SGI2
# ...                               ...      ...      ...      ...
# SCG PACKAGING PLC                D/E2     ROA1     ROE1     SGI2
# REDE D OR SAO LUIZ SA            D/E3     ROA1     ROE3     SGI3
# JD HEALTH INTERNATIONAL INC      D/E1     ROA1     ROE1     SGI2
# CNGR ADVANCED MATERIAL CO        D/E3     ROA2     ROE3     SGI3
# MONTAGE TECHNOLOGY CO LTD        D/E1     ROA3     ROE2     SGI1
#
# [838 rows x 4 columns]

# %%
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(groups).transform(groups)
eg = pd.DataFrame(te_ary, columns=te.columns_)
high_returns = eg.Ret5
eg
# Out:
#       D/E1   D/E2   D/E3   ROA1   ROA2   ROA3   ROE1   ROE2   ROE3   Ret1  \
# 0    False  False   True  False  False   True  False  False   True  False
# 1     True  False  False  False  False   True  False  False   True  False
# 2     True  False  False  False   True  False  False   True  False  False
# 3     True  False  False  False   True  False  False   True  False  False
# 4     True  False  False   True  False  False   True  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 350  False   True  False  False   True  False  False   True  False   True
# 351  False  False   True  False  False   True  False  False   True  False
# 352  False  False   True  False   True  False  False   True  False   True
# 353  False  False   True  False   True  False  False  False   True   True
# 354  False  False   True  False  False   True  False  False   True   True
#
#       Ret2   Ret3   Ret4   Ret5   SGI1   SGI2   SGI3
# 0    False   True  False  False   True  False  False
# 1     True  False  False  False  False   True  False
# 2    False   True  False  False  False  False   True
# 3     True  False  False  False   True  False  False
# 4    False   True  False  False   True  False  False
# ..     ...    ...    ...    ...    ...    ...    ...
# 350  False  False  False  False  False  False   True
# 351   True  False  False  False   True  False  False
# 352  False  False  False  False  False   True  False
# 353  False  False  False  False   True  False  False
# 354  False  False  False  False  False   True  False
#
# [355 rows x 17 columns]

# %%
# Functions that mines assocation and lift rules, the 5th quintile returns and the true/false df for the FPG algorithm
def rules(final):    
    from mlxtend.preprocessing import TransactionEncoder
    # Preprocessing of input argument into true and false for each discretisation 
    te = TransactionEncoder()
    te_ary = te.fit(final).transform(final)
    # Eg is the true/false dataframe in this form for the fp growth algorithm
    eg = pd.DataFrame(te_ary, columns=te.columns_)
    # True/false column of the highest quintile of returns 
    high_returns = eg.Ret5

    # Finding frequent items in data for a minimum support of 5%
    from mlxtend.frequent_patterns import fpgrowth
    freq_items = fpgrowth(eg, min_support=0.05, use_colnames = True)

    from mlxtend.frequent_patterns import association_rules
    # Discover association and causal rules 
    asso_rules = association_rules(freq_items, metric="confidence", min_threshold=0.2)
    lift_rules = association_rules(freq_items, metric="lift", min_threshold=1.2)

    # Return true\false dataframe, high returns, and the found rules
    return eg, high_returns, asso_rules, lift_rules

eg, high_returns, asso_rules, lift_rules = rules(groups)
lift_rules
# Out:
#       antecedents   consequents  antecedent support  consequent support  \
# 0          (D/E3)        (ROA1)            0.332394            0.335211
# 1          (ROA1)        (D/E3)            0.335211            0.332394
# 2          (ROE1)        (D/E3)            0.335211            0.332394
# 3          (D/E3)        (ROE1)            0.332394            0.335211
# 4    (SGI1, D/E3)        (ROA1)            0.112676            0.335211
# ..            ...           ...                 ...                 ...
# 329        (ROA1)  (Ret5, SGI1)            0.335211            0.078873
# 330  (Ret5, ROE1)        (ROA1)            0.067606            0.335211
# 331  (Ret5, ROA1)        (ROE1)            0.087324            0.335211
# 332        (ROE1)  (Ret5, ROA1)            0.335211            0.087324
# 333        (ROA1)  (Ret5, ROE1)            0.335211            0.067606
#
#       support  confidence      lift  leverage  conviction
# 0    0.166197    0.500000  1.491597  0.054775    1.329577
# 1    0.166197    0.495798  1.491597  0.054775    1.324085
# 2    0.123944    0.369748  1.112377  0.012521    1.059268
# 3    0.123944    0.372881  1.112377  0.012521    1.060069
# 4    0.084507    0.750000  2.237395  0.046737    2.659155
# ..        ...         ...       ...       ...         ...
# 329  0.050704    0.151261  1.917767  0.024265    1.085288
# 330  0.059155    0.875000  2.610294  0.036493    5.318310
# 331  0.059155    0.677419  2.020873  0.029883    2.060845
# 332  0.059155    0.176471  2.020873  0.029883    1.108249
# 333  0.059155    0.176471  2.610294  0.036493    1.132193
#
# [334 rows x 9 columns]

# %%
# Function that keeps the rules that imply Return 5 (highest 20% of stocks)
def rules_trim(asso_rules):    
    # For each row, if row does not contain "Ret5", then drop that row from the asso_rules list
    for index in asso_rules.index.tolist():
        if (list(asso_rules.loc[index, 'consequents'])[0] not in ["Ret5"]):
            asso_rules = asso_rules.drop(index, axis=0)
    return asso_rules

hello = rules_trim(lift_rules).sort_values("lift", ascending = False)
hello
# Out:
#       antecedents   consequents  antecedent support  consequent support  \
# 152        (ROE1)  (Ret5, ROA1)            0.334129            0.073986
# 153        (ROA1)  (Ret5, ROE1)            0.334129            0.073986
# 146        (ROE3)  (Ret5, ROA3)            0.332936            0.065632
# 147        (ROA3)  (Ret5, ROE3)            0.332936            0.065632
# 139        (SGI3)        (Ret5)            0.332936            0.200477
# 150  (ROE1, ROA1)        (Ret5)            0.278043            0.200477
# 141        (ROE1)        (Ret5)            0.334129            0.200477
# 143        (ROA1)        (Ret5)            0.334129            0.200477
#
#       support  confidence      lift  leverage  conviction
# 152  0.062053    0.185714  2.510138  0.037332    1.137211
# 153  0.062053    0.185714  2.510138  0.037332    1.137211
# 146  0.051313    0.154122  2.348257  0.029461    1.104612
# 147  0.051313    0.154122  2.348257  0.029461    1.104612
# 139  0.076372    0.229391  1.144223  0.009626    1.037520
# 150  0.062053    0.223176  1.113223  0.006311    1.029220
# 141  0.073986    0.221429  1.104507  0.007000    1.026910
# 143  0.073986    0.221429  1.104507  0.007000    1.026910

# %%
def high_ret_rules(asso_rules):    
    factors = []
    # For each row, if row contains "Ret5", then add that row's antecedents to the factors array
    for index in asso_rules.index.tolist():
        if (list(asso_rules.loc[index, 'consequents'])[0] in ["Ret5"]):
            factors.append(list(asso_rules.loc[index, 'antecedents']))
    return factors

# %%
asso_factors = high_ret_rules(asso_rules)
lift_factors = high_ret_rules(rules_trim(lift_rules).sort_values("lift", ascending = False))

# Make sure that generated association and lift rules 
unique_asso = [i for i in np.unique(asso_factors)]
unique_lift = [i for i in np.unique(lift_factors)]

def get_rules(unique_asso):
    associatons = []
    for asso in unique_asso:
        # Check if each antecedent is in the right format (list)
        if (isinstance(asso, list) == False):
            associatons.append([asso])
        else:
            associatons.append(asso)
    # Return list of lists
    return associatons
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# [['ROA1'], ['ROA3'], ['ROE1'], ['ROE1', 'ROA1'], ['ROE3'], ['SGI3']]

# %%
# Function that retrieves the fair data set for given rules
def get_fair_datasets(true_control, false_control): 
    # Initialise true matches and false matches array
    true_match = []
    false_match = []
    # For every row in the control set that has the rules being true, check if the control variables 
    # from the false set are the same. If so, add row index to true_match and false_match 
    for i in true_control.index:
        for j in false_control.index:
            if (true_control.loc[i, :].tolist() == false_control.loc[j, :].tolist()):
                true_match.append(i)
                false_match.append(j)
    # Return the dates of the fair datasets
    return true_match, false_match

# %%
# Function to get the odds ratio confidence interval for the proposed rule at a 90% confidence level 
def get_oddsratio_CI(exposure, non_exposure, returns):
    # Count for number of times both exposure and non-exposure groups have the consequent 
    n11 = 0
    # Count for number of times the exposure has the consequent and non-exposure groups does not  
    n12 = 0
    # Count for number of times the exposure does not have the consequent and non-exposure groups does
    n21 = 0
    # Count for number of times both exposure and non-exposure groups do not have the consequent
    n22 = 0
    
    for i in range(len(exposure)):
        # If both the exposure and non exposure groups have returns in the 5th quantile, increment n11 by one
        if (returns.loc[exposure.index[i]] == True) and (returns.loc[non_exposure.index[i]] == True):
            n11 += 1
        elif (returns.loc[exposure.index[i]] == True) and (returns.loc[non_exposure.index[i]] == False):
            n12 += 1
        elif (returns.loc[exposure.index[i]] == False) and (returns.loc[non_exposure.index[i]] == True):
            n21 += 1
        elif (returns.loc[exposure.index[i]] == False) and (returns.loc[non_exposure.index[i]] == False):
            n22 += 1

    # To ensure that you are not dividing by 0, if n12 or n21 are zero, set them to one
    if n21 == 0:
        n21 = 1
    if n12 == 0:
        n12 = 1

    # Calculate the odds ratio point estimate 
    odds_ratio = n12/n21

    # Compute the lower and upper bounds of the odds ratio's conficence interval 
    lower_bound = np.exp(np.log(odds_ratio) - (1.64*np.sqrt((1/n12) + (1/n21))))
    upper_bound = np.exp(np.log(odds_ratio) + (1.64*np.sqrt((1/n12) + (1/n21))))
    
    #
    return lower_bound, upper_bound

# %%
# Function that mines causal rules from established associations 
def get_causal_rules(eg, rules, returns):
    # Array to store mined causal rules 
    causal_rules = []
    for rule in rules:
        # If all four factors are included in the associations, include in the causal rules
        if (len(rule) == 4):
            causal_rule.append(rule)
            continue
        else:
            # Otherwise, for each association antecedent, search rows for when antecedent and true and false
            trues = list(np.ones(len(rule), dtype=bool))
            falses = list(np.zeros(len(rule), dtype=bool))
            true = eg[[eg[rule].iloc[i].tolist() == trues for i in range(len(eg[rule]))]]
            false = eg[[eg[rule].iloc[i].tolist() == falses for i in range(len(eg[rule]))]]
            
            # Remove the returns columns and columns with antecedants in question. Only the control variables remain
            remove = ["Ret1", "Ret2", "Ret3", "Ret4", "Ret5"]
            for cond in rule:
                remove.append(cond[:3] + "1")
                remove.append(cond[:3] + "2")
                remove.append(cond[:3] + "3")
            true_control = true.drop(remove, axis = 1)
            false_control = false.drop(remove, axis = 1)
            
            # Drop duplicates from true and false control sets to ensure that there is at most one set of matching rows
            true_control = true_control.drop_duplicates(subset = true_control.columns, keep='first')
            false_control = false_control.drop_duplicates(subset = false_control.columns, keep='first')
            
            # Retrieve the date indices from the fair datasets 
            true_match, false_match = get_fair_datasets(true_control, false_control)    
            
            # Getting returns columns for the rows of the fair dataset 
            exposure_returns = returns[[i in true_match for i in range(len(returns))]]
            non_exposure_returns = returns[[i in false_match for i in range(len(returns))]]
            
            # Compute the bounds of the rule's odd ratio confidence interval
            lower, upper = get_oddsratio_CI(exposure_returns, non_exposure_returns, returns)
            
            #print(rule)
            #print("Odds Ratio Lower Bound: ", lower)
            #print("Odds Ratio Upper Bound: ", upper)
            
            if (lower > 0.5):
                causal_rules.append(rule)
    
    return causal_rules

get_causal_rules(eg, unique_asso, high_returns)
# Out:
# [['D/E3'], ['ROE1'], ['SGI3']]

# %%
next_period_returns = get_date_info(test_dict, 20110930, "201112", "201203")
ranked = rank_factors(next_period_returns)

___ , factors = fpg_prep(ranked)
factors
# Out:
#                              D/E Rank ROA Rank ROE Rank SGI Rank
# Name
# PLDT INC                         D/E3     ROA3     ROE3     SGI1
# ANGLO AMERICAN PLATINUM LTD      D/E1     ROA1     ROE1     SGI2
# SIBANYE-STILLWATER LIMITED       D/E1     ROA3     ROE1     SGI3
# AFRICAN RAINBOW MINERALS LTD     D/E1     ROA3     ROE2     SGI2
# KUALA LUMPUR KEPONG BHD          D/E1     ROA3     ROE3     SGI2
# ...                               ...      ...      ...      ...
# ZHEJIANG CENTURY HUATONG GRP     D/E1     ROA2     ROE1     SGI1
# SUN ART RETAIL GROUP LTD         D/E3     ROA1     ROE2     SGI3
# PARADE TECHNOLOGIES LTD          D/E1     ROA3     ROE2     SGI2
# BOC AVIATION LTD                 D/E3     ROA1     ROE2     SGI2
# SHENNAN CIRCUIT CO               D/E3     ROA1     ROE2     SGI2
#
# [569 rows x 4 columns]

# %%
# Function that finds all stocks that contain the found rules
def get_stocks(factors, rules):
    # Array to store names of companies that appease rules
    checker = []
    for stock in factors.index.unique():
        for factor in rules:
            # If individual rule is a suset of the whole row of factors, then that 
            # company contains the observed rule and is added the checker array
            if (set(factor).issubset(set(factors.loc[stock].values.tolist())) == True) :
                checker.append(stock)
    # Convert checker array to dataframe - then only keep the unique names found
    checker = pd.DataFrame(checker, columns = ["Name"])
    checker = checker.Name.unique()
    # Return unique names found
    return checker

names = get_stocks(factors, unique_lift)
# Out:
# array(['PLDT INC', 'ANGLO AMERICAN PLATINUM LTD',
#        'SIBANYE-STILLWATER LIMITED', 'AFRICAN RAINBOW MINERALS LTD',
#        'PPB GROUP BHD', 'JD.COM INC', 'ALIBABA GROUP HLDG',
#        'ENEL CHILE SA', 'ZTO EXPRESS CAYMAN INC', 'ENEL AMERICAS SA',
#        'GRUPO TELEVISA SAB', 'MANILA ELECTRIC CO',
#        'KEPCO-KOREA ELEC POWER CORP', 'FOMENTO ECONOMICO MEXICANO',
#        'BERGER PAINTS INDIA LTD', 'MARICO LTD', 'GENTING BHD',
#        'SASOL LTD', 'HAP SENG CONSOLIDATED BHD', 'SIME DARBY BHD',
#        'MISC BERHAD', 'TIGER BRANDS LTD', 'NESTLE (MALAYSIA) BHD',
#        'GENTING MALAYSIA BHD', 'IOI CORP BHD',
#        'CHAROEN POKPHAND FOODS PCL', 'INTOUCH HOLDINGS PCL',
#        'SIAM CEMENT PCL', 'ADVANCED INFO SERVICE PCL',
#        'SAMSUNG SDI CO LTD', 'HYUNDAI ENGR & CONSTR CO',
#        'GS ENGINEERING & CONSTRUCTN', 'HYUNDAI STEEL CO',
#        'SAMSUNG ELECTRO-MECHANICS CO', 'LG CORP',
#        'KOREAN AIR LINES CO LTD', 'HANWHA SOLUTIONS CORP',
#        'BTS GROUP HOLDINGS PCL', 'TENAGA NASIONAL BHD', 'CEMEX SAB DE CV',
#        'CITIC LTD', 'OTE - HELLENIC TELECOM ORG', 'SYNNEX TECH INTL CORP',
#        'ENGIE BRASIL ENERGIA SA', 'ULTRAPAR PARTICIPACOES SA',
#        'NETEASE INC', 'TURKCELL ILETISIM HIZMET',
#        'AMERICA MOVIL SA DE CV', 'EXXARO RESOURCES LTD', 'CENCOSUD SA',
#        'LG DISPLAY CO LTD', 'AMERICANAS S A', 'TRINA SOLAR LTD',
#        '3SBIO INC', '360 SECURITY TECHNOLOGY INC', 'ASIAN PAINTS LTD',
#        'AYALA CORP', 'MAHINDRA & MAHINDRA LTD', 'SUZANO SA',
#        'BARITO PACIFIC TBK', 'BERLI JUCKER PCL', 'BHARAT FORGE LTD',
#        'BANGKOK DUSIT MEDICAL SVCS', 'BRITANNIA INDUSTRIES LTD',
#        'MINAS BUENAVENTURA SA', 'BUMRUNGRAD HOSPITAL PCL',
#        'COLGATE-PALMOLIVE (INDIA)', 'BRASKEM SA',
#        'GOME RETAIL HOLDINGS LTD', 'CHAROEN POKPHAND INDONESIA',
#        'CJ CORP', 'CHENG SHIN RUBBER INDUSTRY',
#        'CHINA EVERBRIGHT ENVIRONMENT', 'CHINA RESOURCES BEER (HLDGS)',
#        'NIEN MADE ENTRPRSE', 'YAGEO CORP', 'ELECTRICITY GENERATING PCL',
#        'MARUTI SUZUKI INDIA LTD', 'EMPRESAS CMPC',
#        'EREGLI DEMIR VE CELIK FABRIK', 'EVERGREEN MARINE CORP (TWN)',
#        'FENG TAY ENTRPRISE CO LTD', 'FORMOSA CHEMICAL & FIBER',
#        'FORMOSA PLASTICS CORP', 'VIBRA ENERGIA S.A.', 'GLOBE TELECOM INC',
#        'ZHEJIANG EXPRESSWAY CO LTD', 'JG SUMMIT HOLDINGS INC',
#        'JOLLIBEE FOODS CORP', 'KALBE FARMA', 'KLABIN SA',
#        'HINDUSTAN UNILEVER LTD', 'HYUNDAI MOBIS',
#        'SHENZHEN INTL HLDGS LTD', 'KOC HOLDING AS',
#        'KUMHO PETROCHEMICAL CO LTD', 'SK TELECOM CO LTD',
#        'TAIWAN CEMENT CORP', 'TATA MOTORS LTD', 'TATA STEEL LTD',
#        'TATA POWER CO LTD', 'HANON SYSTEMS', 'NAN YA PLASTICS CORP',
#        'NORTHAM PLATINUM LTD', 'WIPRO LTD', 'SAMSUNG ENGINEERING CO LTD',
#        'LOJAS RENNER SA', 'HOTAI MOTOR CO', 'KGHM POLSKA MIEDZ SA',
#        'WANT WANT CHINA HLDGS LTD', 'FALABELLA SA', 'BRF SA',
#        'TITAN COMPANY LTD', 'DABUR INDIA LTD',
#        'TORRENT PHARMACEUTICALS LTD', 'PETRONAS DAGANGAN',
#        'GIANT MANUFACTURING CO LTD', 'MMG LTD', 'MINOR INTERNATIONAL PCL',
#        'RUENTEX DEVELOPMENT CO LTD', 'WEG SA', 'HOTEL SHILLA LTD',
#        'KOREA ZINC CO LTD', 'YUHAN CORP', 'COMPANHIA SIDERURGICA NACION',
#        'SIEMENS LTD', 'HUABAO INTL HLDGS LTD', 'VEDANTA LTD',
#        'UNI-PRESIDENT ENTERPRISE CO', 'PRESS METAL ALUMNIUM HLD BHD',
#        'PTT EXPLORATION & PRODUCTION', 'AC ENERGY CORPORATION',
#        'UNILEVER INDONESIA', 'UNITED MICROELECTRONICS CORP',
#        'UNITED TRACTORS', 'BEIJING ENTERPRISES WATER GR',
#        'WUS PRINTED CIRCUIT CO LTD', 'GREEN CROSS CORP (KOREA)',
#        'BANGKOK EXPRESSWAY AND METRO', 'PETRONAS GAS',
#        'DELTA ELECTRONICS (THAILAND)', 'UNITED SPIRITS LTD',
#        'LIVZON PHARMACEUTICAL GROUP', 'INFOSYS LTD', 'SRF LTD',
#        'BALKRISHNA INDS', 'BHARAT ELECTRONICS LTD',
#        'ASPEN PHARMACARE HLDGS LTD', 'PIDILITE INDUSTRIES LTD',
#        'SHOPRITE HLDGS LTD', 'SHREE CEMENT', 'MR PRICE GROUP LTD',
#        'EICHER MOTORS', 'JSW STEEL LTD', 'ORION CORP',
#        'TUPRAS-TURKIYE PETROL RAFINE', 'MTN GROUP LTD',
#        'ACCTON TECHNOLOGY CORP', 'WINBOND ELECTRONICS CORP', 'HMM CO LTD',
#        'SUN PHARMACEUTICAL INDS LTD', 'ALIBABA PICTURES GROUP LTD',
#        'WAN HAI LINES LTD', 'INDIAN OIL CORP LTD', 'INVENTEC CO LTD',
#        'FOXCONN TECHNOLOGY CO LTD', 'SOQUIMIC COMERCIAL SA',
#        'COSCO SHIPPING PORTS LTD', 'SKC CO LTD', 'DIALOG GROUP BHD',
#        'WOOLWORTHS HLDGS LTD', 'INDOCEMENT TUNGGAL PRAKARSA',
#        'FRASER & NEAVE HOLDINGS BHD', 'FORD OTOMOTIV SANAYI AS',
#        'TURK SISE CAM', 'ALPARGATAS SA', 'CJ LOGISTICS CORP',
#        'SAMSUNG HEAVY INDUSTRIES CO', 'EMPRESAS COPEC SA',
#        'ASTRA INTERNATIONAL TBK (PT)', 'TELEFONICA BRASIL SA',
#        'BHARAT PETROLEUM CO LTD', 'HERO MOTOCORP LTD',
#        'HINDUSTAN PETROLEUM CORP LTD', 'TRENT LTD',
#        'PIRAMAL ENTERPRISES LTD', "DR REDDY'S LABORATORIES LTD",
#        'LOTTE CHEMICAL CORP', 'S-OIL CORP', 'MICRO-STAR INTERNATIONAL CO',
#        'QUANTA COMPUTER INC', 'PRESIDENT CHAIN STORE CORP',
#        'DIGI.COM BHD', 'HENGAN INTERNATIONAL GROUP',
#        'ADANI ENTERPRISES LTD', 'HCL TECHNOLOGIES LTD',
#        'BEIJING CAPITAL INTL AIRPORT', 'VANGUARD INTL SEMICONDUCTOR',
#        'FAW JIEFANG GROUP CO LTD', 'MALAYSIA AIRPORTS HLDGS BHD',
#        'KOREA SHIPBUILDING & OFFSHOR', 'REMGRO LTD',
#        'NANYA TECHNOLOGY CO LTD', 'CHUNGHWA TELECOM LTD',
#        'ALIBABA HEALTH INFO TECH LTD', 'CHINA GAS HOLDINGS LTD',
#        'COWAY CO LTD', 'AU OPTRONICS CORP', 'CJ ENM CO LTD',
#        'LG UPLUS CORP', 'ADVANTECH CO LTD',
#        'SHANGHAI INTL AIRPORT CO LTD', 'CHINA GREATWALL TECHNOLOGY',
#        'HLB CO LTD', 'ANHUI GUJING DISTILLERY CO',
#        'CHINA ZHENHUA SCIENCE & TECH', 'LUZHOU LAOJIAO CO LTD',
#        'MPHASIS BFL LTD', 'SAIC MOTOR CORP LTD',
#        'SHANGHAI YUYUAN TOURIST MART', 'SHANXI XING HUA CUN FEN WINE',
#        'CHINA BAOAN GROUP CO LTD', 'JONJEE HI-TECH INDL & COML',
#        'SICHUAN CHUANTOU HOLDING CO', 'KINGDEE INTL SOFTWARE GRP CO',
#        'RUMO SA', 'NOVATEK MICROELECTRONICS CO', 'OPAP SA',
#        'LG H&H CO LTD', 'DOOSAN ENERBILITY CO LTD', 'MEDIA TEK INC',
#        'CATCHER TECHNOLOGY CO LTD', 'TRAVELSKY TECHNOLOGY LTD',
#        'CONTAINER CORP (INDIA)', 'NATL INDUSTRIALIZATION CO',
#        'SAVOLA GROUP', 'SABIC AGRI-NUTRIENTS COMPANY',
#        'SAUDI BASIC INDUSTRIES CORP', 'PTT PLC',
#        'INTERCONEXION ELECTRICA SA', 'PUBLIC POWER CORP SA',
#        'ECLAT TEXTILE CO LTD', 'HOME PRODUCT CENTER PCL',
#        'QL RESOURCES BHD', 'CD PROJEKT SA', 'BHARTI AIRTEL LTD',
#        'LG ELECTRONICS INC', 'FIBERHOME TELECOMMUNICATION',
#        'KWEICHOW MOUTAI CO LTD', 'YOUNGOR GROUP CO LTD',
#        'XCMG CONST MACHINERY CO LTD', 'HUNAN VALIN STEEL TUBE & WIR',
#        'GUANGHUI ENERGY CO LTD', 'PANGANG GRP VANADIUM TITANIU',
#        'GD POWER DEVELOPMENT CO LTD', 'SHANGHAI CONSTRUCTION CO',
#        'JOINCARE PHARMACEUTICAL GRP', 'SHANXI TAIGANG STAINLESS STL',
#        'SHENZHEN ENERGY GROUP CO LTD', 'ENN ENERGY HOLDINGS LTD',
#        'LARGAN PRECISION CO LTD', 'KANGWON LAND INC',
#        'FAR EASTONE TELECOMMUNICTN', 'CHINA RUYI HOLDINGS LIMITED',
#        'BYD COMPANY LTD', 'OFFSHORE OIL ENGINEERING CO', 'NAVER CORP',
#        'SINOTRANS LTD', 'CCR SA', "DIVI'S LABORATORIES LTD",
#        'HEILONGJIANG AGRICULTURE CO', 'SHENGYI TECHNOLOGY CO LTD',
#        'XIAMEN FARATRONIC CO', 'CP ALL PCL', 'GODREJ CONSUMER PRODUCT',
#        'SAMVARDHANA MOTHERSON', 'YONYOU NETWORK TECHNOLOGY CO',
#        'HUAGONG TECH CO LTD', 'CHINA YANGTZE POWER CO',
#        'NEW HOPE LIUHE CO LTD', 'FORMOSA PETROCHEMI',
#        'BEIJING TIANTAN BIOLOGICAL', 'ZOOMLION HEAVY IND SCIENCE',
#        'CHINA JUSHI CO LTD', 'GREE ELEC APPLLIANCES INC',
#        'HENAN SHUANGHUI INVT & DEV', 'HANGZHOU HUADONG MEDICINE CO',
#        'HENGTONG OPTIC-ELEC CO LTD', 'NINGBO SHANSHAN CO LTD',
#        'HUAYU AUTOMOTIVE SYSTEMS CO', 'SHANGHAI FOSUN PHARMACEUTICL',
#        'SHANGHAI JAHWA UNITED CO LTD', 'SANY HEAVY IND CO LTD',
#        'DONG-E E JIAO CO LTD', 'SHANDONG NANSHAN ALUMINIUM',
#        'SHANGHAI ELECTRIC POWER CO', 'SHANXI COKING CO LTD',
#        'CHINA MINMETALS RARE EARTH', 'SICHUAN NEW ENERGY POWER CO',
#        'TSINGHUA UNISPLENDOUR CORP', 'XIAMEN C & D INC',
#        'WANHUA CHEMICAL GROUP CO LTD', 'YUNNAN ALUMINIUM CO LTD',
#        'ZHEJIANG LONGSHENG GROUP CO', 'AVICHINA IND & TECH CO LTD',
#        'UPL LTD', 'AIRPORTS OF THAILAND PCL', 'LOCALIZA RENT A CAR SA',
#        'NTPC LTD', 'POLISH OIL AND GAS CO', 'ALROSA PJSC',
#        'ENERGISA S.A.', 'ROSNEFT OIL COMPANY',
#        'NAN YA PRINTED CIRCUIT BOARD', 'TAIWAN HIGH SPEED RAIL CORP',
#        'SDIC POWER HOLDINGS CO LTD', 'YUNNAN TIN CO LTD',
#        'INDRAPRASTHA GAS LTD', 'SHANDONG GOLD MINING CO LTD',
#        'CHONGQING FULING ELEC POWER', 'CHIFENG JILONG GOLD MINING',
#        'CHINA MENGNIU DAIRY CO', 'NATURA &CO HOLDING SA',
#        'NARI TECHNOLOGY CO LTD', 'TCL TECHNOLOGY GROUP CORP',
#        'GS HOLDINGS CORP', 'TENCENT HOLDINGS LTD',
#        'KINGFA SCI & TECH CO LTD', 'LI NING CO LTD',
#        'HANGZHOU SILAN MICROELECT', 'TRANSFAR ZHILIAN CO LTD',
#        'ZHEJIANG NHU COMPANY LTD', 'ZHANGZHOU PIENTZEHUANG',
#        'JIANGSU YANGNONG CHEMICAL', 'XIAMEN TUNGSTEN CO LTD',
#        'SHENGHE RESOURCES HOLDING CO', 'SHANDONG HUALU HENGSHENG CHE',
#        'SUNING.COM CO LTD', 'SICHUAN ROAD & BRIDGE GROUP',
#        'JIANGSU ZHONG TIAN TECH CO', 'ULTRA TECH CEMENT LTD',
#        'DAAN GENE CO LTD', 'SIYUAN ELECTRIC CO LTD',
#        'TATA CONSULTANCY SVCS LTD', 'FOCUS MEDIA INFO TECH CO LTD',
#        'ZHEJIANG SUPOR CO', 'SINO BIOPHARMACEUTICAL LTD',
#        'TONGLING NONFERROUS METAL', 'CHONG QING BREWERY CO LTD',
#        'CHINA NORTHERN RARE EARTH', 'TEBIAN ELECTRIC APPARTUS STK',
#        'CHINA POWER INTL DEVELOPMENT', 'SPAR GROUP LTD', 'THAI OIL PCL',
#        'YINTAI GOLD CO LTD', 'ZHEJIANG JUHUA CO LTD', 'PETRONET LNG LTD',
#        'TIANMA MICROELECTRONICS CO', 'YUAN LONGPING AGR HIGH-TECH',
#        'YUNNAN BAIYAO GROUP CO LTD', 'POSCO CHEMICAL CO LTD',
#        'HENGYI PETROCHEMICAL CO LTD', 'APELOA PHARMACEUTICAL CO LTD',
#        'AECC AERO-ENGINE CONTROL CO', 'SHANXI MEIJIN ENERGY CO LTD',
#        'JIUGUI LIQUOR CO LTD', 'TOPCHOICE MEDICAL CORP',
#        'BEIJING SHUNXIN AGRICULTURE', 'HUBEI XINGFA CHEMICALS GRP',
#        'CHANGCHUN NEW & HIGH TECH', 'NORTH INDUSTRIES GRP RED ARR',
#        'INSPUR ELECTRONIC INFO', 'CECEP SOLAR ENERGY CO LTD',
#        'YTO EXPRESS GROUP CO LTD', 'SOUTHWEST SECURITIES CO LTD',
#        'TIBET SUMMIT INDUSTRIAL CO', 'GUANGZHOU YUEXIU FINANCIAL',
#        'ANGEL YEAST CO LTD', 'ADDSINO CO LTD',
#        'HENGLI PETROCHEMICAL CO LTD', 'AECC AVIATION POWER CO LTD',
#        'WINGTECH TECHNOLOGY CO LTD', 'FANGDA CARBON NEW MAT CO LTD',
#        'HONGFA TECHNOLOGY CO LTD', 'AVIC ELECTROMECHANICAL SYS',
#        'CHENGTUN MINING GROUP CO LTD', 'WUCHAN ZHONGDA GROUP CO LTD',
#        'SM INVESTMENTS CORP', 'MEINIAN ONEHEALTH HEALTHCARE',
#        'ZHEJIANG SANHUA INTELLIGENT', 'UNIGROUP GUOXIN MICROELECTRO',
#        'BIM BIRLESIK MAGAZALAR', 'CELLTRION INC', 'L & F CO',
#        'CHINA STATE CONSTRUCTION', 'ETIHAD ETISALAT CO',
#        'SAUDI ELECTRICITY CO', 'ETISALAT GROUP', 'ALMARAI CO',
#        'WPG HOLDINGS', 'COSAN SA', 'SHENZHOU INTL GROUP HOLDINGS',
#        'DONGFENG MOTOR GROUP CO', 'PTT GLOBAL CHEMICAL PCL',
#        'HYUNDAI GLOVIS CO LTD', 'MABANEE CO', 'JARIR MARKETING CO',
#        'JBS SA', 'CELLTRION PHARM INC', 'FOSUN INTERNATIONAL LTD',
#        'HAVELLS INDIA LTD', 'HUTCHMED (CHINA) LTD', 'AMOREPACIFIC CORP',
#        'DAQIN RAILWAY CO LTD', 'EQUATORIAL ENERGIA SA',
#        'HUAFON CHEMICAL CO LTD', 'DHC SOFTWARE CO LTD',
#        'SHANXI LUAN ENVIRONMENTAL EN', 'TECH MAHINDRA LTD',
#        'SHANDONG SUNPAPER CO LTD', 'SHANGHAI INTL PORT GROUP',
#        'XINJIANG ZHONGTAI CHEMICAL', 'KUMBA IRON ORE LTD',
#        'INFO EDGE (INDIA) LTD', 'CHINA COMMUNICATION SVCS',
#        'ZHUZHOU CRRC TIMES ELEC CO', 'HAITIAN INTL HLDGS LTD',
#        'ADVANCED PETROCHEMICAL CO', 'SAHARA INTERNL PETROCHEMICAL',
#        'YANBU NATIONAL PETROCHEMICAL', 'YUNDA HOLDING CO LTD',
#        'MINDTREE LTD', 'PAGE INDUSTRIES LTD',
#        'SUNNY OPTICAL TECH GROUP CO', 'SK INNOVATION CO LTD',
#        'ANTA SPORTS PRODUCTS', 'HIWIN TECHNOLOGIES CORP',
#        'CHINA MEDICAL SYSTEM HLDG', 'SAUDI KAYAN PETROCHEMICAL CO',
#        'BEIJING BDSTAR NAVIGATION CO', 'BEIJING SHIJI INFO TECH',
#        'CNNC HUA YUAN TITANIUM DIOX', 'GRG BANKING EQUIPMENT CO LTD',
#        'TONGFU MICROELECTRONICS CO', 'JIANGXI ZHENGBANG TECHNOLOGY',
#        'CJ CHEILJEDANG CORP', 'KINGSOFT CO LTD',
#        'BOSIDENG INTERNATIONAL HLDG', 'NINESTAR CORP',
#        'TIANSHUI HUATIAN TECH CO LTD', 'CHINA RAILWAY GROUP LTD',
#        'YOUNGY CO LTD', 'SINOTRUK (HONG KONG) LTD', 'DONGYUE GROUP LTD',
#        'XINJIANG GOLDWIND SCI & TECH', 'UNI-PRESIDENT CHINA HLDG LTD',
#        'ECOPETROL SA', 'TOPSEC TECHNOLOGIES GROUP',
#        'RABIGH REFINING & PETROCHEM', 'EMEMORY TECHNOLOGY INC',
#        'JIANGSU YUYUE MED EQUIP & SU', 'AXIATA GROUP BHD',
#        'IFLYTEK CO LTD', 'CHENGXIN LITHIUM GROUP CO',
#        'ZHEJIANG DAHUA TECHNOLOGY CO', 'BAJAJ AUTO LTD',
#        'SHANGHAI RAAS BLOOD PRODUCTS', 'HARTALEGA HOLDINGS BHD',
#        'ZHEFU HOLDING GROUP CO LTD', 'WESTONE INFORMATION IND INC',
#        'SAUDI ARABIAN MINING CO', 'LG INNOTEK CO LTD',
#        'ABDULLAH AL OTHAIM MARKETS', 'SHENZHEN SALUBRIS PHARMA',
#        'MOUWASAT MEDICAL SVCS', 'CHINA TOURISM GRP DUTY FREE',
#        'FUJIAN SUNNER DEVELOPMENT CO', 'LEPU MEDICAL TECHNOLOGY',
#        'EVE ENERGY CO LTD', 'AIER EYE HOSPITAL GRP CO LTD',
#        'JIANGSU YANGHE BREWERY JSC', 'GUANGDONG HAID GROUP CO LTD',
#        'SK INC', 'MAXIS BHD', 'ZHEJIANG YONGTAI TECHNOLOGY',
#        'HITHINK ROYALFLUSH INFO', 'POLSKA GRUPA ENERGETYCZNA SA',
#        'SHENZHEN CAPCHEM TECHNOLOGY', 'CHINA NATIONAL CHEMICAL ENG',
#        'ZHEJIANG CHINT ELECTRICS CO', 'YANTAI JEREH OILFIELD SVCS',
#        'INDORAMA VENTURES PCL', 'JUBILANT FOODWORKS LTD',
#        'NAURA TECHNOLOGY GROUP CO', 'SARANA MENARA NUSANTARA',
#        'CHINA TRANSINFO TECHNOLOGY', 'PI INDUSTRIES',
#        'SUZHOU DONGSHAN PRECISION MA', 'EAST MONEY INFO CO LTD',
#        'ZHONGSHENG GROUP HLDGS LTD', 'BEIJING ORIGIN WATER TECH CO',
#        'BEIJING EASPRING MATL TECH', 'NAVINFO CO LTD',
#        'DO-FLUORIDE NEW MATERIALS CO', 'ZIBO QIXIANG TENGDA CHEM CO',
#        'JIANGSU YOKE TECHNOLOGY CO', 'WUHAN GUIDE INFRARED CO LTD',
#        'SICHUAN KELUN PHARMA CO LTD', 'PEGATRON CORP',
#        'OFILM GROUP CO LTD', 'GUANGZHOU HAIGE COM GROUP IN',
#        'CHONGQING ZHIFEI BIOLOGICAL', 'SHENZHEN INOVANCE TECHNOLOGY',
#        'SEEGENE INC', 'MICROPORT SCIENTIFIC CORP',
#        'INDOFOOD CBP SUKSES MAKMUR', 'CHINA SUNTIEN GREEN ENERGY',
#        'RONGSHENG PETROCHEMICAL CO', 'SICHUAN YAHUA INDUSTRIAL GRP',
#        'SHENZHEN SUNWAY COMM CO LTD', 'PETRO RIO SA',
#        'WALVAX BIOTECHNOLOGY CO LTD', 'JOINTOWN PHARMA GROUP CO LTD',
#        'TOWER BERSAMA INFRASTRUCTUR', 'COAL INDIA LTD',
#        'GCL SYSTEM INTEGRATION TECH', 'HANGZHOU ROBAM APPLIANCES CO',
#        'PETRONAS CHEMICALS GROUP', 'SONGCHENG PERFORMANCE DVLPMT',
#        'BY-HEALTH CO LTD', 'YONGHUI SUPERSTORES CO LTD',
#        'AIRTAC INTERNATIONAL GROUP', 'TITAN WIND ENERGY (SUZHOU)',
#        'ANHUI HONGLU STEEL CONSTRUCT', 'CHANGZHOU XINGYU AUTOMOTIVE',
#        'GIANT NETWORK GROUP CO LTD', 'INNER MONGOLIA JUNZHENG ENE',
#        'ILJIN MATERIALS CO', 'SHANGHAI BAIRUN INV HOLDING',
#        'CHINA HONGQIAO GROUP LTD', 'SUNWODA ELECTRONIC CO LTD',
#        'TONGKUN GROUP CO LTD', 'BEIJING E-HUALU INFO TECH CO',
#        'MAGAZINE LUIZA SA', 'SAILUN GROUP CO LTD',
#        'KOREA AEROSPACE IND LTD', 'LB GROUP CO LTD', 'INARI AMERTRON BHD',
#        'ZHEJIANG CENTURY HUATONG GRP', 'SHIJIAZHUANG YILING PHARMA',
#        'BEIJING ENLIGHT MEDIA CO LTD', 'ZHUZHOU KIBING GROUP CO LTD',
#        'WINNING HEALTH TECH GROUP CO', 'JIANGSU HENGLI HYDRAULIC CO',
#        'PERFECT WORLD CO LTD', 'PARADE TECHNOLOGIES LTD',
#        'KUANG-CHI TECHNLOGIES CO LTD', 'SATELLTTE CHEMICAL CO LTD',
#        'ASMEDIA TECHNOLOGY INC', 'UNIVERSAL SCIENTIFIC INDL SH',
#        'LEYARD OPTO ELECTRONIC CO', 'ZHONGJI INNOLIGHT CO LTD',
#        'LONGI GREEN ENERGY TECH', 'ZHEJIANG JINGSHENG MECHANICA',
#        'BOC AVIATION LTD', 'IHH HEALTHCARE BERHAD',
#        'HEFEI MEYER OPTOELECTRONIC', 'SICHUAN HEBANG BIOTECHNOLOGY',
#        'HANGZHOU TIGERMED CONSULT', 'HANKOOK TIRE & TECHNOLOGY CO',
#        'ENERGY ABSOLUTE PUBLIC CO', 'VOLTRONIC POWER TECH CORP',
#        'WESTPORTS HOLDINGS BHD', 'XINYI SOLAR HOLDINGS', 'SILERGY CORP',
#        'CHINA MEIDONG AUTO HOLDINGS', 'CHINA CONCH VENTURE HOLDINGS',
#        'GUANGZHOU TINCI MAT TECH CO', 'ZHEJIANG WOLWO BIO PHARM CO',
#        'BEIJING SINNET TECHNOLOGY CO', 'MUYUAN FOODSTUFF CO LTD',
#        'SHAANXI COAL IND CO LTD', 'FOSHAN HAITIAN FLAVOURING',
#        'MOMO.COM INC', "JIANGSU KING'S LUCK BREWERY",
#        'SUZHOU TA&A ULTRA CLEAN TECH', 'HANGZHOU FIRST APPLIED MATER',
#        'CECEP WIND-POWER CORP', 'HUA HONG SEMICONDUCTOR',
#        'ZHEJIANG JIUZHOU PHARM CO', 'GLOBALWAFERS CO LTD',
#        'SAMSUNG SDS CO LTD', 'CARABAO GROUP PUBLIC CO',
#        'CHAOZHOU THREE-CIRCLE GROUP', 'CGN POWER CO LTD', 'ALTEOGEN INC',
#        'KUNLUN TECH CO LTD', 'SHANGHAI M&G STATIONERY',
#        'ZHEJIANG HUAYOU COBALT CO', 'YIFENG PHARMACY CHAIN',
#        'LENS TECHNOLOGY CO', 'MIANYANG FULIN PRECISION',
#        'NINGBO TUOPU GROUP CO LTD', 'ZHEJIANG DINGLI MACHINERY',
#        'LBX PHARMACY CHAIN JSC', 'GLOBAL POWER SYNERGY PCL',
#        'ANHUI YINGJIA DISTILLERY CO', 'ZHEJIANG WEIMING ENVIRONMENT',
#        'ADANI TRANSMISSION LTD', 'CHINA NATIONAL NUCLEAR',
#        'MERDEKA COPPER GOLD TBK', 'ANHUI KOUZI DISTILLERY CO',
#        'CHINA RAILWAY SIGNAL & COMM', 'WENS FOODSTUFF GROUP CO LTD',
#        'INTERGLOBE AVIATION LTD', 'DALI FOODS GROUP CO LTD',
#        'FLAT GLASS GROUP CO LTD', 'CHINA ENERGY ENGINEERING',
#        'TELESITES SAB DE CV', 'GENSCRIPT BIOTECH CORP',
#        'GUANGDONG KINLONG HARDWARE', 'YADEA GROUP HOLDINGS LTD',
#        'SKSHU PAINT CO LTD', 'YIHAI INTERNATIONAL HOLDING',
#        'LARSEN & TOUBRO INFOTECH', 'JAFRON BIOMEDICAL CO LTD',
#        'GIGADEVICE SEMICONDUCTOR', 'JASON FURNITURE (HANGZHOU)',
#        'SAMSUNG BIOLOGICS CO LTD', 'BETTA PHARMACEUTICALS CO LTD',
#        'PC1 GROUP JOINT STOCK CO', 'SHENZHEN SENIOR TECH MAT',
#        'RIYUE HEAVY INDUSTRY CO', 'G-BITS NETWORK TEC',
#        'YANTAI EDDIE PRECISION', 'BECLE SAB DE CV',
#        'SHENZHEN KANGTAI BIOLOGICAL', 'SHENZHEN KEDALI INDUSTRY CO',
#        'AVENUE SUPERMARTS LTD', 'YEALINK NETWORK TECH CO LTD',
#        'JUEWEI FOOD CO LTD', 'OPPEIN HOME GROUP INC', 'DINO POLSKA SA',
#        'HD HYUNDAI CO LTD', 'NETMARBLE CORPORATION', 'SG MICRO CORP',
#        'WUXI BIOLOGICS (CAYMAN) INC', 'NANJING KING-FRIEN', 'ATACADAO SA',
#        'BGI GENOMICS CO LT', 'B.GRIMM POWER PLC', 'DASHENLIN PHARMACE',
#        'INTCO MEDICAL TECHNOLOGY CO', 'CELLTRION HEALTHCA',
#        'JOINN LABORATORIES', 'WEIHAI GUANGWEI CO', 'PEPKOR HOLDINGS LTD',
#        'HOSHINE SILICON IN', 'PHARMABLOCK SCIENC', 'WIWYNN CORPORATION',
#        'PROYA COSMETICS CO', 'ZHUZHOU HONGDA ELE', 'GULF ENERGY DEVELO',
#        'BGF RETAIL CO LTD', 'SHENNAN CIRCUIT CO', 'HUIZHOU DESAY SV A',
#        'SK CHEMICALS', 'XIAMEN INTRETECH INC', 'TIANJIN 712 COMMUN',
#        'PING AN HLTH & TECH', 'WUXI APPTEC CO LTD', 'SANGFOR TECHNOLOGI',
#        'ECOVACS ROBOTICS C', 'CONTEMPORARY AMPER', 'ADANI GREEN ENERGY',
#        'XIAOMI CORPORATION', 'CHINA TOWER CORPORATION LTD', 'MEITUAN',
#        'ADANI TOTAL GAS LTD', 'HAIDILAO INTL HOLDING LTD',
#        'AVARY HOLDING (SHE', 'SHENZHEN MINDRAY B', 'INNOVENT BIOLOGICS',
#        'SUZHOU MAXWELL TEC', 'MANGO EXCELLENT MEDIA CO LTD',
#        'JIANGSU EASTERN SHENGHONG CO', 'TONGCHENG TRAVEL HOLDINGS',
#        'SHANGHAI JUNSHI BI', 'WUXI SHANGJI AUTOMATION CO', 'WEIMOB INC',
#        'MING YANG SMART ENERGY GROUP', 'MULTICHOICE GROUP LTD',
#        'GINLONG TECHNOLOGIES CO LTD', 'NINGXIA BAOFENG ENERGY GROUP',
#        'LAKALA PAYMENT CORP', 'BEIJING YUANLIU HONGYUAN ELE',
#        'HANSOH PHARMA GROUP CO LTD', 'JINXIN FERTILITY GROUP LTD',
#        'MAXSCEND MICROELEC', 'YANTAI RAYTRON TECHNOLOGY CO',
#        'NINGBO RONBAY NEW ENERGY TEC', 'ZHEJIANG HANGKE TECHNO INCOR',
#        'BEIJING UNITED INFO TECH CO', 'FAWRY BANKING & PAYMT TECH',
#        'SHANGHAI FRIENDESS ELECTRO', 'ASSET WORLD CORP PUBLIC CO',
#        'INDIAN RAILWAY CATERING', 'SHANGHAI MEDICILON INC',
#        'SAUDI ARABIAN OIL CO', 'CHINA FEIHE LTD',
#        'BEIJING KINGSOFT OFFICE', 'JA SOLAR TECHNOLOGY CO LTD',
#        'VENUS MEDTECH (HANGZHOU) INC', 'BEIJING-SHANGHAI HIGH-SPEED',
#        'JIUMAOJIU INTERNATIONAL', 'STARPOWER SEMICONDUCTOR LTD',
#        'CENTRAL RETAIL CORP PCL', 'AUTEL INTELLIGENT TECHNOLOGY',
#        'BEIJING ROBOROCK T', 'DR. SULAIMAN AL HABIB',
#        'BEIJING WANTAI BIOLOGICAL', 'NATIONAL SILICON INDUSTRY GR',
#        'KBC CORPORATION LTD', 'SRI TRANG GLOVES (THAILAND)',
#        'HYGEIA HEALTHCARE HOLDINGS', 'SMOORE INTERNATIONAL HOLDING',
#        'NONGFU SPRING CO LTD', 'MING YUAN CLOUD GRP HOLDINGS',
#        'YIHAI KERRY ARAWANA HOLDINGS', 'IMEIK TECHNOLOGY DEVELOPMENT',
#        'HYBE CO LTD', 'SCG PACKAGING PLC', 'REDE D OR SAO LUIZ SA',
#        'JD HEALTH INTERNATIONAL INC', 'CNGR ADVANCED MATERIAL CO',
#        'PTT OIL AND RETAIL BUSINESS', 'KUAISHOU TECHNOLOGY',
#        'MONTAGE TECHNOLOGY CO LTD', 'CHINA THREE GORGES RENEWABLE'],
#       dtype=object)

# %%
def six_month_returns(rets, stock_names, date1, date2):
    returns = []
    available_stocks = len(stock_names)
    for stock in stock_names:
        array = [rets[stock][rets[stock].Date == date1].values.tolist()[0][-1],
                        rets[stock][rets[stock].Date == date2].values.tolist()[0][-1]]
        array = [x+1 for x in array]
        returns.append((np.cumprod(array)[-1]-1))

    if (available_stocks == 0):
        return 0.0
    #print("Length of Returns: ", len(returns))
    #print("Number of Stocks: ", len(stock_names))

    return (sum(returns)/available_stocks)

# %%
# Function to calculate the six-month equal-weighted portfolio returns 
def six_month_returns1(rets, stock_names, date1, date2):
    # Array to store the six-month returns of each stock in the portfolio
    returns = []
    # Counter to number of stocks available 
    available_stocks = len(stock_names)
    for stock in stock_names:
        # For each stock, check if the six_month return information is available. If so, calculate six-month returns 
        # and append the returns array
        try:
            array = [rets[stock][rets[stock].Date == date1].values.tolist()[0][-1],
                        rets[stock][rets[stock].Date == date2].values.tolist()[0][-1]]
            array = [x+1 for x in array]
            returns.append((np.cumprod(array)[-1]-1))
        # If stock is not available, reduce the number of stocks in the portfolio and continue to the next stock
        except IndexError:
            available_stocks -= 1
            continue

    #print("Length of Returns: ", len(returns))
    #print("Number of Stocks: ", len(stock_names))
    
    # Returnb the portfolio 6-month return
    return (sum(returns)/available_stocks)

# %%
# Setting up years for the simulation period
years = np.arange(2005, 2022)
dates = []
# For each year, create the ending dates of the four quarters 
for year in years:
    q1 = str(year) + "0331"
    q2 = str(year) + "0630"
    q3 = str(year) + "0930"
    q4 = str(year) + "1231"
    # Add dates to dates array
    dates.append(int(q1))
    dates.append(int(q2))
    dates.append(int(q3))
    dates.append(int(q4))

# %%
# Simulation start at Q1 2006 (position four in the dates array above)
i = 4
# Array to store quarterly dates and returns of the rule mining strategies 
records4 = []
records5 = []
records6 = []

# Store the names of all portfolio formation throghout the simulation's history
all_asso_names = []
all_lift_names = []
all_causal_names = []
# While there are still two dates ahead of the rebalancing date; mine rules, rebalance portfolios, and calculate returns
while (i < 66):
    # Retrieve fundamental information from six months ago and their 6-month forward return
    info = get_date_info(test_dict, dates[i-2], str(dates[i-1])[:6], str(dates[i])[:6])

    # Retrieve the ranked information
    groups, ranks = fpg_prep(rank_factors(info))
    # Retrieve the true/false dataframe, high returns column, and association and lift rules for these ranks factors 
    eg, high_returns, asso_rules, lift_rules = rules(groups)
    
    # Keep only the rules that imply Return 5
    asso_factors = high_ret_rules(asso_rules)
    lift_factors = high_ret_rules(rules_trim(lift_rules).sort_values("lift", ascending = False))

    # Keep only the unique antecedents and make sure it is in the format list of lists
    unique_asso = [i for i in np.unique(asso_factors)]
    unique_lift = [i for i in np.unique(lift_factors)]
    unique_lift = get_rules(unique_lift)
    unique_asso = get_rules(unique_asso)
    
    # From the unique association antecedents, mine causal rules 
    causal_rules = get_causal_rules(eg, unique_asso, high_returns)

    #print(unique_asso)
    #print(unique_lift)
    
    # Get the fundamental information at the rebalance (current) date and discretise
    next_period_returns = get_date_info(test_dict, dates[i], str(dates[i+1])[:6], str(dates[i+2])[:6])
    ranked = rank_factors(next_period_returns)
    ___ , factors = fpg_prep(ranked)
    
    # Get names of stocks that satisfy the lift rules 
    lift_names = get_stocks(factors, unique_lift)
    
    # If the names or rules are non-zero, rebalance portfolios and calculate returns 
    if (len(lift_names) != 0 or len(unique_lift) != 0):
        rebalance = "Yes"
        all_lift_names.append(lift_names)
        add1 = [str(dates[i+2])[:6], len(unique_lift), len(lift_names), six_month_returns1(quarterly_rets, lift_names, 
                                                  str(dates[i+1])[:6], str(dates[i+2])[:6]), rebalance]
    # If no names or rules found, then do not rebalance the portfolio and calculate the six month 
    # returns of the same portfolio as the previous period
    elif (len(lift_names) == 0 or len(unique_lift) == 0):
        rebalance = "No"
        add1 = [str(dates[i+2])[:6], len(causal_rules), len(all_lift_names[-1]), six_month_returns1(quarterly_rets, 
                        all_lift_names[-1],  str(dates[i+1])[:6], str(dates[i+2])[:6]), rebalance]
    
    asso_names = get_stocks(factors, unique_asso)
    # If the names or rules are non-zero, rebalance portfolios and calculate returns 
    if (len(asso_names) != 0 or len(unique_asso) != 0):
        rebalance = "Yes"
        all_asso_names.append(asso_names)
        add2 = [str(dates[i+2])[:6], len(unique_asso), len(asso_names), six_month_returns1(quarterly_rets, asso_names, 
                                                str(dates[i+1])[:6], str(dates[i+2])[:6]), rebalance]
     # If no names or rules found, then do not rebalance the portfolio and calculate the six month 
    # returns of the same portfolio as the previous period
    elif (len(asso_names) == 0 or len(unique_asso) == 0):
        rebalance = "No"
        add2 = [str(dates[i+2])[:6], len(causal_rules), len(all_asso_names[-1]), six_month_returns1(quarterly_rets, 
                        all_asso_names[-1],  str(dates[i+1])[:6], str(dates[i+2])[:6]), rebalance]
    
    causal_names = get_stocks(factors, causal_rules)
    # If the names or rules are non-zero, rebalance portfolios and calculate returns 
    if (len(causal_names) != 0 or len(causal_rules) != 0):
        rebalance = "Yes"
        all_causal_names.append(causal_names)
        add3 = [str(dates[i+2])[:6], len(causal_rules), len(causal_names), six_month_returns1(quarterly_rets, 
                          causal_names, str(dates[i+1])[:6], str(dates[i+2])[:6]), rebalance]
    # If no names or rules found, then do not rebalance the portfolio and calculate the six month 
    # returns of the same portfolio as the previous period
    elif (len(causal_names) == 0 or len(causal_rules) == 0):
        rebalance = "No"
        add3 = [str(dates[i+2])[:6], len(causal_rules), len(all_causal_names[-1]), six_month_returns1(quarterly_rets, 
                        all_causal_names[-1],  str(dates[i+1])[:6], str(dates[i+2])[:6]), rebalance]
 
    # Append arrays with date, number of rules found, number of stocks in portfolio, 6M returns, and if there was rebalancing
    records4.append(add1)
    records5.append(add2)
    records6.append(add3)
    i+=2
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
# For each strategy's returns, create dataframe of results
stuff4 = pd.DataFrame(records4, columns = ["Date", "Number of Rules", "Number of Stocks", "6M Returns", "Rebalance?"])
stuff4 = stuff4.set_index("Date")
stuff4

stuff5 = pd.DataFrame(records5, columns = ["Date", "Number of Rules", "Number of Stocks", "6M Returns", "Rebalance?"])
stuff5 = stuff5.set_index("Date")
stuff5

stuff6 = pd.DataFrame(records6, columns = ["Date", "Number of Rules", "Number of Stocks", "6M Returns", "Rebalance?"])
stuff6 = stuff6.set_index("Date")
stuff4
# Out:
#         Number of Rules  Number of Stocks  6M Returns Rebalance?
# Date
# 200609                6               217    0.275187        Yes
# 200703                9               279    0.651629        Yes
# 200709                8               235    0.692008        Yes
# 200803                6               300   -0.076007        Yes
# 200809                4               247   -0.254247        Yes
# 200903                8               336    0.038374        Yes
# 200909                7               321    0.525510        Yes
# 201003               10               410    0.308702        Yes
# 201009                7               436    0.223522        Yes
# 201103                8               429    0.153118        Yes
# 201109                5               397   -0.096111        Yes
# 201203                5               418    0.170529        Yes
# 201209                9               599    0.016300        Yes
# 201303                8               510    0.139696        Yes
# 201309                8               529    0.132981        Yes
# 201403                7               555    0.100934        Yes
# 201409                4               333    0.181408        Yes
# 201503                8               460    0.209468        Yes
# 201509                5               510   -0.112339        Yes
# 201603                7               449    0.139610        Yes
# 201609                6               562    0.088551        Yes
# 201703                4               460    0.084949        Yes
# 201709                6               621    0.175006        Yes
# 201803                4               432    0.179288        Yes
# 201809                6               493   -0.078582        Yes
# 201903                8               511    0.136800        Yes
# 201909                6               667    0.011060        Yes
# 202003                4               457    0.033044        Yes
# 202009                6               542    0.552121        Yes
# 202103                6               703    0.285499        Yes
# 202109                6               739    0.189284        Yes

# %%
# Printing cumulative returns for each strategy
print(stuff6["6M Returns"].mean())
print((stuff4["6M Returns"].add(1).cumprod(axis = 0)[-1])-1)
print((stuff5["6M Returns"].add(1).cumprod(axis = 0)[-1])-1)
print((stuff6["6M Returns"].add(1).cumprod(axis = 0)[-1])-1)
# Out:
# 0.17125369191055126
# 66.41780819920496
# 53.826947923896796
# 75.55780245497127

# %%
# Calculating and printing annualised returns for each strategy
annualised_return_4 = ((stuff4["6M Returns"].add(1).cumprod(axis = 0)[-1])**(1/16) - 1)*100
print("Lift rules returns: ", round(annualised_return_4, 2))

annualised_return_5 = ((stuff5["6M Returns"].add(1).cumprod(axis = 0)[-1])**(1/16) - 1)*100
print("Association rules returns: ", round(annualised_return_5, 2))

annualised_return_6 = ((stuff6["6M Returns"].add(1).cumprod(axis = 0)[-1])**(1/16) - 1)*100
print("Causal AR returns: ", round(annualised_return_6, 2))
# Out:
# Lift rules returns:  30.11
# Association rules returns:  28.44
# Causal AR returns:  31.14

# %%
from sklearn.linear_model import LinearRegression

x = np.array(stuff5["6M Returns"]).reshape((-1,1))
x

y = np.array(stuff6["6M Returns"])
y

model = LinearRegression().fit(x, y)
model.intercept_

# %%
print(stuff4["6M Returns"].describe())
1.167445**2

# %%
def sim():  
    import random
    i = 4
    records4 = []
    records5 = []
    records6 = []

    all_asso_names = []
    all_lift_names = []
    all_causal_names = []
    while (i < 66):
        info = get_date_info(test_dict, dates[i-2], str(dates[i-1])[:6], str(dates[i])[:6])

        sup = rank_factors(info)
        groups, ranks = fpg_prep(sup)
        eg, high_returns, asso_rules, lift_rules = rules(groups)

        asso_factors = high_ret_rules(asso_rules)
        lift_factors = high_ret_rules(rules_trim(lift_rules).sort_values("lift", ascending = False))

        unique_asso = [i for i in np.unique(asso_factors)]
        unique_lift = [i for i in np.unique(lift_factors)]

        unique_lift = get_rules(unique_lift)
        unique_asso = get_rules(unique_asso)

        causal_rules = get_causal_rules(eg, unique_asso, high_returns)

            #print(unique_asso)
            #print(unique_lift)

        next_period_returns = get_date_info(test_dict, dates[i], str(dates[i+1])[:6], str(dates[i+2])[:6])
        ranked = rank_factors(next_period_returns)

        ___ , factors = fpg_prep(ranked)

        lift_names = get_stocks(factors, unique_lift)

        if (len(lift_names) != 0 or len(unique_lift) != 0):
            rebalance = "Yes"
            all_lift_names.append(lift_names)
            add1 = [str(dates[i+2])[:6], len(unique_lift), len(lift_names), six_month_returns1(quarterly_rets, 
                                list(random.sample(set(lift_names), min(250, len(lift_names)))), str(dates[i+1])[:6], str(dates[i+2])[:6]), rebalance]
        elif (len(lift_names) == 0 or len(unique_lift) == 0):
            rebalance = "No"
            #previous_names = list(set(factors.index.unique()) & set(all_lift_names[-1]))
            add1 = [str(dates[i+2])[:6], len(causal_rules), len(all_lift_names[-1]), six_month_returns1(quarterly_rets, 
                           list(random.sample(set(all_lift_names[-1]), min(250, len(all_lift_names[-1])))),  str(dates[i+1])[:6], str(dates[i+2])[:6]), rebalance]

        asso_names = get_stocks(factors, unique_asso)

        if (len(asso_names) != 0 or len(unique_asso) != 0):
            rebalance = "Yes"
            all_asso_names.append(asso_names)
            add2 = [str(dates[i+2])[:6], len(unique_asso), len(asso_names), six_month_returns1(quarterly_rets, 
                            list(random.sample(set(asso_names), min(250, len(asso_names)))), str(dates[i+1])[:6], str(dates[i+2])[:6]), rebalance]
        elif (len(asso_names) == 0 or len(unique_asso) == 0):
            rebalance = "No"
            #previous_names = list(set(factors.index.unique()) & set(all_asso_names[-1]))
            add2 = [str(dates[i+2])[:6], len(causal_rules), len(all_asso_names[-1]), six_month_returns1(quarterly_rets, 
                            list(random.sample(set(all_asso_names[-1]), min(250,len(all_asso_names[-1])))), str(dates[i+1])[:6], str(dates[i+2])[:6]), rebalance]

        causal_names = get_stocks(factors, causal_rules)

        if (len(causal_names) != 0 or len(causal_rules) != 0):
            rebalance = "Yes"
            all_causal_names.append(causal_names)
            add3 = [str(dates[i+2])[:6], len(causal_rules), len(causal_names), six_month_returns1(quarterly_rets, 
                                  list(random.sample(set(causal_names), min(250, len(causal_names)))), str(dates[i+1])[:6], str(dates[i+2])[:6]), rebalance]
        elif (len(causal_names) == 0 or len(causal_rules) == 0):
            rebalance = "No"
            #previous_names = list(set(factors.index.unique()) & set(all_causal_names[-1]))
            add3 = [str(dates[i+2])[:6], len(causal_rules), len(all_causal_names[-1]), six_month_returns1(quarterly_rets, 
                                list(random.sample(set(all_causal_names[-1]), min(250, len(all_causal_names[-1])))), str(dates[i+1])[:6], str(dates[i+2])[:6]), rebalance]

        records4.append(add1)
        records5.append(add2)
        records6.append(add3)
        i+=2

    return records4, records5, records6

lift_ret, asso_ret, causal_ret = sim()

lift = pd.DataFrame(lift_ret, columns = ["Date", "Number of Rules", "Number of Stocks", "6M Returns", "Rebalance?"])
lift = lift.set_index("Date")


asso = pd.DataFrame(asso_ret, columns = ["Date", "Number of Rules", "Number of Stocks", "6M Returns", "Rebalance?"])
asso = asso.set_index("Date")

causal = pd.DataFrame(causal_ret, columns = ["Date", "Number of Rules", "Number of Stocks", "6M Returns", "Rebalance?"])
causal = causal.set_index("Date")
causal
